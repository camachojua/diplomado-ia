# %%
using CSV
using DataFrames
using BenchmarkTools
using Tables
using Statistics
using Query
using CUDA
using Dates
using Printf
using Parquet

# %%
# Cargar el archivo CSV de películas (movies.csv)
movies_df = CSV.read("movies.csv", DataFrame)
println("Archivo de películas cargado con éxito.")
# Out:
# Archivo de películas cargado con éxito.

# %%
using Parquet

function dividir_archivo_csv_linea_por_linea(archivo, filas_por_fragmento)
    start_time = now()  # Tiempo de inicio

    # Inicializar variables para el procesamiento
    i = 1
    contador_filas = 0
    df_fragmento = DataFrame()

    # Abrir el archivo CSV y leer línea por línea
    for row in CSV.File(archivo)
        push!(df_fragmento, row)
        contador_filas += 1

        # Guardar el fragmento cuando se alcanza el número de filas por fragmento
        if contador_filas >= filas_por_fragmento
            nombre_parquet = "ratings_" * lpad(i, 2, '0') * ".parquet"
            Parquet.write_parquet(nombre_parquet, df_fragmento)
            println("Fragmento guardado: $nombre_parquet")

            # Reiniciar el DataFrame y el contador de filas
            df_fragmento = DataFrame()
            contador_filas = 0
            i += 1
        end
    end

    # Guardar cualquier fila restante en un último fragmento
    if nrow(df_fragmento) > 0
        nombre_parquet = "ratings_" * lpad(i, 2, '0') * ".parquet"
        Parquet.write_parquet(nombre_parquet, df_fragmento)
        println("Último fragmento guardado: $nombre_parquet")
    end

    end_time = now()  # Tiempo de finalización
    println("Tiempo total para dividir el archivo: ", end_time - start_time)
end

# Llamar a la función con el nombre del archivo y el tamaño del fragmento
dividir_archivo_csv_linea_por_linea("ratings.csv", 500000)
# Out:
# Fragmento guardado: ratings_01.parquet
# Fragmento guardado: ratings_02.parquet
# Fragmento guardado: ratings_03.parquet
# Fragmento guardado: ratings_04.parquet
# Fragmento guardado: ratings_05.parquet
# Fragmento guardado: ratings_06.parquet
# Fragmento guardado: ratings_07.parquet
# Fragmento guardado: ratings_08.parquet
# Fragmento guardado: ratings_09.parquet
# Fragmento guardado: ratings_10.parquet
# Fragmento guardado: ratings_11.parquet
# Fragmento guardado: ratings_12.parquet
# Fragmento guardado: ratings_13.parquet
# Fragmento guardado: ratings_14.parquet
# Fragmento guardado: ratings_15.parquet
# Fragmento guardado: ratings_16.parquet
# Fragmento guardado: ratings_17.parquet
# Fragmento guardado: ratings_18.parquet
# Fragmento guardado: ratings_19.parquet
# Fragmento guardado: ratings_20.parquet
# Fragmento guardado: ratings_21.parquet
# Fragmento guardado: ratings_22.parquet
# Fragmento guardado: ratings_23.parquet
# Fragmento guardado: ratings_24.parquet
# Fragmento guardado: ratings_25.parquet
# Fragmento guardado: ratings_26.parquet
# Fragmento guardado: ratings_27.parquet
# Fragmento guardado: ratings_28.parquet
# Fragmento guardado: ratings_29.parquet
# Fragmento guardado: ratings_30.parquet
# Fragmento guardado: ratings_31.parquet
# Fragmento guardado: ratings_32.parquet
# Fragmento guardado: ratings_33.parquet
# Fragmento guardado: ratings_34.parquet
# Fragmento guardado: ratings_35.parquet
# Fragmento guardado: ratings_36.parquet
# Fragmento guardado: ratings_37.parquet
# Fragmento guardado: ratings_38.parquet
# Fragmento guardado: ratings_39.parquet
# Fragmento guardado: ratings_40.parquet
# Fragmento guardado: ratings_41.parquet
# Fragmento guardado: ratings_42.parquet
# Fragmento guardado: ratings_43.parquet
# Fragmento guardado: ratings_44.parquet
# Fragmento guardado: ratings_45.parquet
# Fragmento guardado: ratings_46.parquet
# Fragmento guardado: ratings_47.parquet
# Fragmento guardado: ratings_48.parquet
# Fragmento guardado: ratings_49.parquet
# Fragmento guardado: ratings_50.parquet
# Último fragmento guardado: ratings_51.parquet
# Tiempo total para dividir el archivo: 40011 milliseconds

# %%
using Parquet, DataFrames, CSV

# Cargar el archivo de películas
movies_df = CSV.read("movies.csv", DataFrame)
println("Archivo de películas cargado con éxito.")

function procesar_fragmento(worker_id, generos_conocidos, arreglo_conteo, arreglo_valor, movies_df)
    nombre_fragmento = "ratings_" * lpad(worker_id, 2, '0') * ".parquet"
    println("Intentando procesar fragmento: $nombre_fragmento")

    try
        # Cargar el archivo Parquet directamente como un DataFrame
        ratings_df = Parquet.read_parquet(nombre_fragmento) |> DataFrame
        println("Fragmento cargado exitosamente: $nombre_fragmento")
    catch e
        println("Error al cargar $nombre_fragmento: $e")
        return
    end

    try
        # Usar innerjoin en lugar de join!
        ratings_df = innerjoin(ratings_df, movies_df, on=:movieId)
        println("Join completado para fragmento: $nombre_fragmento")
    catch e
        println("Error en join de $nombre_fragmento: $e")
        return
    end

    ratings_df = select(ratings_df, [:genres, :rating])
    println("Columnas filtradas para fragmento: $nombre_fragmento")

    for row in eachrow(ratings_df)
        for i in 1:length(generos_conocidos)
            if occursin(generos_conocidos[i], row.genres)
                arreglo_conteo[i][worker_id] += 1
                arreglo_valor[i][worker_id] += row.rating
            end
        end
    end

    println("Worker $worker_id ha terminado de procesar $nombre_fragmento")
end

# Parámetros de prueba
generos_conocidos = ["Action", "Adventure", "Animation", "Children", "Comedy", "Crime", "Documentary",
                     "Drama", "Fantasy", "Film-Noir", "Horror", "IMAX", "Musical", "Mystery", "Romance",
                     "Sci-Fi", "Thriller", "War", "Western", "(no genres listed)"]
numero_generos = length(generos_conocidos)

arreglo_conteo = [zeros(Int, 1) for _ in 1:numero_generos]
arreglo_valor = [zeros(Float64, 1) for _ in 1:numero_generos]

# Llamar a procesar_fragmento solo para el fragmento 1
procesar_fragmento(1, generos_conocidos, arreglo_conteo, arreglo_valor, movies_df)
# Out:
# Archivo de películas cargado con éxito.
# Intentando procesar fragmento: ratings_01.parquet
# Fragmento cargado exitosamente: ratings_01.parquet
# Join completado para fragmento: ratings_01.parquet
# Columnas filtradas para fragmento: ratings_01.parquet
# Worker 1 ha terminado de procesar ratings_01.parquet

# %%
# Función para consolidar resultados y procesar los archivos en paralelo
function procesar_archivo_multihilo(num_procesos)
    println("El orquestador del proceso ha iniciado su ejecución.")
    
    generos_conocidos = ["Action", "Adventure", "Animation", "Children", "Comedy", "Crime", "Documentary",
                         "Drama", "Fantasy", "Film-Noir", "Horror", "IMAX", "Musical", "Mystery", "Romance",
                         "Sci-Fi", "Thriller", "War", "Western", "(no genres listed)"]
    numero_generos = length(generos_conocidos)

    arreglo_conteo = [zeros(Int, num_procesos) for _ in 1:numero_generos]
    arreglo_valor = [zeros(Float64, num_procesos) for _ in 1:numero_generos]

    Threads.@threads for i in 1:num_procesos
        procesar_fragmento(i, generos_conocidos, arreglo_conteo, arreglo_valor, movies_df)
    end

    locCount = zeros(Int, numero_generos)
    locVals = zeros(Float64, numero_generos)
    locAvg = zeros(Float64, numero_generos)  # Nuevo arreglo para el promedio

    for i in 1:numero_generos
        for j in 1:num_procesos
            locCount[i] += arreglo_conteo[i][j]
            locVals[i] += arreglo_valor[i][j]
        end
        # Calcular el promedio solo si hay calificaciones para el género
        locAvg[i] = locCount[i] > 0 ? locVals[i] / locCount[i] : 0
    end

    # Imprimir resultados finales
    for i in 1:numero_generos
        println("Género: ", generos_conocidos[i], " | Calificaciones: ", locCount[i], 
                " | Suma de Ratings: ", locVals[i], " | Promedio de Rating: ", locAvg[i])
    end

    println("Fin del orquestador.")
end

# Llamar a la función de procesamiento en paralelo
procesar_archivo_multihilo(51)  # Cambia el número según el número de fragmentos
# Out:
# El orquestador del proceso ha iniciado su ejecución.
# Intentando procesar fragmento: ratings_14.parquet
# Intentando procesar fragmento: ratings_27.parquet
# Intentando procesar fragmento: ratings_40.parquet
# Intentando procesar fragmento: ratings_01.parquet
# Fragmento cargado exitosamente: ratings_27.parquet
# Fragmento cargado exitosamente: ratings_14.parquet
# Fragmento cargado exitosamente: ratings_40.parquet
# Fragmento cargado exitosamente: ratings_01.parquet
# Join completado para fragmento: ratings_27.parquet
# Join completado para fragmento: ratings_01.parquet
# Join completado para fragmento: ratings_14.parquet
# Columnas filtradas para fragmento: ratings_01.parquet
# Columnas filtradas para fragmento: ratings_27.parquet
# Columnas filtradas para fragmento: ratings_14.parquet
# Join completado para fragmento: ratings_40.parquet
# Columnas filtradas para fragmento: ratings_40.parquet
# Worker 40 ha terminado de procesar ratings_40.parquet
# Intentando procesar fragmento: ratings_41.parquet
# Fragmento cargado exitosamente: ratings_41.parquet
# Worker 14 ha terminado de procesar ratings_14.parquet
# Intentando procesar fragmento: ratings_15.parquet
# Join completado para fragmento: ratings_41.parquet
# Worker 1 ha terminado de procesar ratings_01.parquet
# Intentando procesar fragmento: ratings_02.parquet
# Columnas filtradas para fragmento: ratings_41.parquet
# Worker 27 ha terminado de procesar ratings_27.parquet
# Intentando procesar fragmento: ratings_28.parquet
# Fragmento cargado exitosamente: ratings_15.parquet
# Fragmento cargado exitosamente: ratings_28.parquet
# Join completado para fragmento: ratings_15.parquet
# Fragmento cargado exitosamente: ratings_02.parquet
# Join completado para fragmento: ratings_28.parquet
# Columnas filtradas para fragmento: ratings_15.parquet
# Columnas filtradas para fragmento: ratings_28.parquet
# Join completado para fragmento: ratings_02.parquet
# Columnas filtradas para fragmento: ratings_02.parquet
# Worker 28 ha terminado de procesar ratings_28.parquet
# Intentando procesar fragmento: ratings_29.parquet
# Fragmento cargado exitosamente: ratings_29.parquet
# Join completado para fragmento: ratings_29.parquet
# Columnas filtradas para fragmento: ratings_29.parquet
# Worker 41 ha terminado de procesar ratings_41.parquet
# Intentando procesar fragmento: ratings_42.parquet
# Fragmento cargado exitosamente: ratings_42.parquet
# Join completado para fragmento: ratings_42.parquet
# Columnas filtradas para fragmento: ratings_42.parquet
# Worker 15 ha terminado de procesar ratings_15.parquet
# Intentando procesar fragmento: ratings_16.parquet
# Worker 2 ha terminado de procesar ratings_02.parquet
# Intentando procesar fragmento: ratings_03.parquet
# Fragmento cargado exitosamente: ratings_16.parquet
# Fragmento cargado exitosamente: ratings_03.parquet
# Join completado para fragmento: ratings_16.parquet
# Join completado para fragmento: ratings_03.parquet
# Columnas filtradas para fragmento: ratings_16.parquet
# Columnas filtradas para fragmento: ratings_03.parquet
# Worker 29 ha terminado de procesar ratings_29.parquet
# Intentando procesar fragmento: ratings_30.parquet
# Fragmento cargado exitosamente: ratings_30.parquet
# Join completado para fragmento: ratings_30.parquet
# Columnas filtradas para fragmento: ratings_30.parquet
# Worker 42 ha terminado de procesar ratings_42.parquet
# Intentando procesar fragmento: ratings_43.parquet
# Fragmento cargado exitosamente: ratings_43.parquet
# Join completado para fragmento: ratings_43.parquet
# Columnas filtradas para fragmento: ratings_43.parquet
# Worker 16 ha terminado de procesar ratings_16.parquet
# Intentando procesar fragmento: ratings_17.parquet
# Fragmento cargado exitosamente: ratings_17.parquet
# Join completado para fragmento: ratings_17.parquet
# Columnas filtradas para fragmento: ratings_17.parquet
# Worker 3 ha terminado de procesar ratings_03.parquet
# Intentando procesar fragmento: ratings_04.parquet
# Fragmento cargado exitosamente: ratings_04.parquet
# Join completado para fragmento: ratings_04.parquet
# Columnas filtradas para fragmento: ratings_04.parquet
# Worker 30 ha terminado de procesar ratings_30.parquet
# Intentando procesar fragmento: ratings_31.parquet
# Fragmento cargado exitosamente: ratings_31.parquet
# Join completado para fragmento: ratings_31.parquet
# Columnas filtradas para fragmento: ratings_31.parquet
# Worker 43 ha terminado de procesar ratings_43.parquet
# Intentando procesar fragmento: ratings_44.parquet
# Fragmento cargado exitosamente: ratings_44.parquet
# Join completado para fragmento: ratings_44.parquet
# Columnas filtradas para fragmento: ratings_44.parquet
# Worker 4 ha terminado de procesar ratings_04.parquet
# Intentando procesar fragmento: ratings_05.parquet
# Worker 17 ha terminado de procesar ratings_17.parquet
# Intentando procesar fragmento: ratings_18.parquet
# Fragmento cargado exitosamente: ratings_05.parquet
# Fragmento cargado exitosamente: ratings_18.parquet
# Join completado para fragmento: ratings_05.parquet
# Columnas filtradas para fragmento: ratings_05.parquet
# Join completado para fragmento: ratings_18.parquet
# Columnas filtradas para fragmento: ratings_18.parquet
# Worker 31 ha terminado de procesar ratings_31.parquet
# Intentando procesar fragmento: ratings_32.parquet
# Fragmento cargado exitosamente: ratings_32.parquet
# Join completado para fragmento: ratings_32.parquet
# Columnas filtradas para fragmento: ratings_32.parquet
# Worker 44 ha terminado de procesar ratings_44.parquet
# Intentando procesar fragmento: ratings_45.parquet
# Fragmento cargado exitosamente: ratings_45.parquet
# Join completado para fragmento: ratings_45.parquet
# Columnas filtradas para fragmento: ratings_45.parquet
# Worker 5 ha terminado de procesar ratings_05.parquet
# Intentando procesar fragmento: ratings_06.parquet
# Fragmento cargado exitosamente: ratings_06.parquet
# Join completado para fragmento: ratings_06.parquet
# Columnas filtradas para fragmento: ratings_06.parquet
# Worker 18 ha terminado de procesar ratings_18.parquet
# Intentando procesar fragmento: ratings_19.parquet
# Fragmento cargado exitosamente: ratings_19.parquet
# Join completado para fragmento: ratings_19.parquet
# Columnas filtradas para fragmento: ratings_19.parquet
# Worker 32 ha terminado de procesar ratings_32.parquet
# Intentando procesar fragmento: ratings_33.parquet
# Fragmento cargado exitosamente: ratings_33.parquet
# Join completado para fragmento: ratings_33.parquet
# Columnas filtradas para fragmento: ratings_33.parquet
# Worker 45 ha terminado de procesar ratings_45.parquet
# Intentando procesar fragmento: ratings_46.parquet
# Fragmento cargado exitosamente: ratings_46.parquet
# Join completado para fragmento: ratings_46.parquet
# Columnas filtradas para fragmento: ratings_46.parquet
# Worker 6 ha terminado de procesar ratings_06.parquet
# Intentando procesar fragmento: ratings_07.parquet
# Fragmento cargado exitosamente: ratings_07.parquet
# Join completado para fragmento: ratings_07.parquet
# Columnas filtradas para fragmento: ratings_07.parquet
# Worker 19 ha terminado de procesar ratings_19.parquet
# Intentando procesar fragmento: ratings_20.parquet
# Fragmento cargado exitosamente: ratings_20.parquet
# Join completado para fragmento: ratings_20.parquet
# Columnas filtradas para fragmento: ratings_20.parquet
# Worker 33 ha terminado de procesar ratings_33.parquet
# Intentando procesar fragmento: ratings_34.parquet
# Fragmento cargado exitosamente: ratings_34.parquet
# Join completado para fragmento: ratings_34.parquet
# Columnas filtradas para fragmento: ratings_34.parquet
# Worker 7 ha terminado de procesar ratings_07.parquet
# Intentando procesar fragmento: ratings_08.parquet
# Worker 46 ha terminado de procesar ratings_46.parquet
# Intentando procesar fragmento: ratings_47.parquet
# Fragmento cargado exitosamente: ratings_08.parquet
# Fragmento cargado exitosamente: ratings_47.parquet
# Join completado para fragmento: ratings_08.parquet
# Join completado para fragmento: ratings_47.parquet
# Columnas filtradas para fragmento: ratings_08.parquet
# Columnas filtradas para fragmento: ratings_47.parquet
# Worker 34 ha terminado de procesar ratings_34.parquet
# Intentando procesar fragmento: ratings_35.parquet
# Fragmento cargado exitosamente: ratings_35.parquet
# Join completado para fragmento: ratings_35.parquet
# Columnas filtradas para fragmento: ratings_35.parquet
# Worker 20 ha terminado de procesar ratings_20.parquet
# Intentando procesar fragmento: ratings_21.parquet
# Fragmento cargado exitosamente: ratings_21.parquet
# Join completado para fragmento: ratings_21.parquet
# Columnas filtradas para fragmento: ratings_21.parquet
# Worker 35 ha terminado de procesar ratings_35.parquet
# Intentando procesar fragmento: ratings_36.parquet
# Fragmento cargado exitosamente: ratings_36.parquet
# Join completado para fragmento: ratings_36.parquet
# Columnas filtradas para fragmento: ratings_36.parquet
# Worker 47 ha terminado de procesar ratings_47.parquet
# Intentando procesar fragmento: ratings_48.parquet
# Fragmento cargado exitosamente: ratings_48.parquet
# Join completado para fragmento: ratings_48.parquet
# Columnas filtradas para fragmento: ratings_48.parquet
# Worker 8 ha terminado de procesar ratings_08.parquet
# Intentando procesar fragmento: ratings_09.parquet
# Fragmento cargado exitosamente: ratings_09.parquet
# Join completado para fragmento: ratings_09.parquet
# Columnas filtradas para fragmento: ratings_09.parquet
# Worker 21 ha terminado de procesar ratings_21.parquet
# Intentando procesar fragmento: ratings_22.parquet
# Fragmento cargado exitosamente: ratings_22.parquet
# Join completado para fragmento: ratings_22.parquet
# Columnas filtradas para fragmento: ratings_22.parquet
# Worker 36 ha terminado de procesar ratings_36.parquet
# Intentando procesar fragmento: ratings_37.parquet
# Fragmento cargado exitosamente: ratings_37.parquet
# Join completado para fragmento: ratings_37.parquet
# Columnas filtradas para fragmento: ratings_37.parquet
# Worker 48 ha terminado de procesar ratings_48.parquet
# Intentando procesar fragmento: ratings_49.parquet
# Fragmento cargado exitosamente: ratings_49.parquet
# Join completado para fragmento: ratings_49.parquet
# Columnas filtradas para fragmento: ratings_49.parquet
# Worker 9 ha terminado de procesar ratings_09.parquet
# Intentando procesar fragmento: ratings_10.parquet
# Worker 22 ha terminado de procesar ratings_22.parquet
# Intentando procesar fragmento: ratings_23.parquet
# Fragmento cargado exitosamente: ratings_10.parquet
# Fragmento cargado exitosamente: ratings_23.parquet
# Join completado para fragmento: ratings_10.parquet
# Columnas filtradas para fragmento: ratings_10.parquet
# Join completado para fragmento: ratings_23.parquet
# Columnas filtradas para fragmento: ratings_23.parquet
# Worker 37 ha terminado de procesar ratings_37.parquet
# Intentando procesar fragmento: ratings_38.parquet
# Fragmento cargado exitosamente: ratings_38.parquet
# Join completado para fragmento: ratings_38.parquet
# Columnas filtradas para fragmento: ratings_38.parquet
# Worker 49 ha terminado de procesar ratings_49.parquet
# Intentando procesar fragmento: ratings_50.parquet
# Fragmento cargado exitosamente: ratings_50.parquet
# Worker 10 ha terminado de procesar ratings_10.parquet
# Intentando procesar fragmento: ratings_11.parquet
# Join completado para fragmento: ratings_50.parquet
# Columnas filtradas para fragmento: ratings_50.parquet
# Fragmento cargado exitosamente: ratings_11.parquet
# Join completado para fragmento: ratings_11.parquet
# Columnas filtradas para fragmento: ratings_11.parquet
# Worker 23 ha terminado de procesar ratings_23.parquet
# Intentando procesar fragmento: ratings_24.parquet
# Fragmento cargado exitosamente: ratings_24.parquet
# Join completado para fragmento: ratings_24.parquet
# Columnas filtradas para fragmento: ratings_24.parquet
# Worker 38 ha terminado de procesar ratings_38.parquet
# Intentando procesar fragmento: ratings_39.parquet
# Fragmento cargado exitosamente: ratings_39.parquet
# Join completado para fragmento: ratings_39.parquet
# Columnas filtradas para fragmento: ratings_39.parquet
# Worker 50 ha terminado de procesar ratings_50.parquet
# Intentando procesar fragmento: ratings_51.parquet
# Fragmento cargado exitosamente: ratings_51.parquet
# Join completado para fragmento: ratings_51.parquet
# Columnas filtradas para fragmento: ratings_51.parquet
# Worker 51 ha terminado de procesar ratings_51.parquet
# Worker 11 ha terminado de procesar ratings_11.parquet
# Intentando procesar fragmento: ratings_12.parquet
# Fragmento cargado exitosamente: ratings_12.parquet
# Join completado para fragmento: ratings_12.parquet
# Columnas filtradas para fragmento: ratings_12.parquet
# Worker 24 ha terminado de procesar ratings_24.parquet
# Intentando procesar fragmento: ratings_25.parquet
# Fragmento cargado exitosamente: ratings_25.parquet
# Join completado para fragmento: ratings_25.parquet
# Columnas filtradas para fragmento: ratings_25.parquet
# Worker 39 ha terminado de procesar ratings_39.parquet
# Worker 12 ha terminado de procesar ratings_12.parquet
# Intentando procesar fragmento: ratings_13.parquet
# Fragmento cargado exitosamente: ratings_13.parquet
# Join completado para fragmento: ratings_13.parquet
# Columnas filtradas para fragmento: ratings_13.parquet
# Worker 25 ha terminado de procesar ratings_25.parquet
# Intentando procesar fragmento: ratings_26.parquet
# Fragmento cargado exitosamente: ratings_26.parquet
# Join completado para fragmento: ratings_26.parquet
# Columnas filtradas para fragmento: ratings_26.parquet
# Worker 13 ha terminado de procesar ratings_13.parquet
# Worker 26 ha terminado de procesar ratings_26.parquet
# Género: Action | Calificaciones: 7446918 | Suma de Ratings: 2.58154245e7 | Promedio de Rating: 3.4665917497681593
# Género: Adventure | Calificaciones: 5832424 | Suma de Ratings: 2.05152285e7 | Promedio de Rating: 3.517444633654892
# Género: Animation | Calificaciones: 1630987 | Suma de Ratings: 5.8959305e6 | Promedio de Rating: 3.614946348438093
# Género: Children | Calificaciones: 2124258 | Suma de Ratings: 7.2915315e6 | Promedio de Rating: 3.4325074920278045
# Género: Comedy | Calificaciones: 8926230 | Suma de Ratings: 3.0563345e7 | Promedio de Rating: 3.4239925478057365
# Género: Crime | Calificaciones: 4190259 | Suma de Ratings: 1.54412875e7 | Promedio de Rating: 3.685043693003225
# Género: Documentary | Calificaciones: 322449 | Suma de Ratings: 1.194764e6 | Promedio de Rating: 3.7052805249822454
# Género: Drama | Calificaciones: 10962833 | Suma de Ratings: 4.03123615e7 | Promedio de Rating: 3.677184674800756
# Género: Fantasy | Calificaciones: 2831585 | Suma de Ratings: 9.9433625e6 | Promedio de Rating: 3.5115889157486
# Género: Film-Noir | Calificaciones: 247227 | Suma de Ratings: 970546.0 | Promedio de Rating: 3.9257281769386028
# Género: Horror | Calificaciones: 1892183 | Suma de Ratings: 6.2320245e6 | Promedio de Rating: 3.2935633075659174
# Género: IMAX | Calificaciones: 1063279 | Suma de Ratings: 3.8317515e6 | Promedio de Rating: 3.6037121959523324
# Género: Musical | Calificaciones: 964252 | Suma de Ratings: 3.427642e6 | Promedio de Rating: 3.554715987107105
# Género: Mystery | Calificaciones: 2010995 | Suma de Ratings: 7.380692e6 | Promedio de Rating: 3.670169244577933
# Género: Romance | Calificaciones: 4497291 | Suma de Ratings: 1.59326075e7 | Promedio de Rating: 3.5427121571630567
# Género: Sci-Fi | Calificaciones: 4325740 | Suma de Ratings: 1.5045544e7 | Promedio de Rating: 3.4781433928067798
# Género: Thriller | Calificaciones: 6763272 | Suma de Ratings: 2.3826766e7 | Promedio de Rating: 3.5229643285084498
# Género: War | Calificaciones: 1267346 | Suma de Ratings: 4.805099e6 | Promedio de Rating: 3.7914657875591984
# Género: Western | Calificaciones: 483731 | Suma de Ratings: 1.734541e6 | Promedio de Rating: 3.5857553061515595
# Género: (no genres listed) | Calificaciones: 26627 | Suma de Ratings: 88571.5 | Promedio de Rating: 3.326379239118188
# Fin del orquestador.
