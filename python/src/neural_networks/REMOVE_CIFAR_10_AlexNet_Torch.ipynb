# %% [markdown]
# ### LeNet in Pytorch
#
# + This notebook shows how to use PyTorch (and TorchVision) for Image Classification.
#
# + The dataset is CIFAR-10, a dataset that defines 10 classes and contains 6K images per class, for a total of 60K images.
#
# + 50K Images are for training and 10K for testing.
#
# + The images are (32,32) RGBs
#
#         + https://www.cs.toronto.edu/~kriz/cifar.html
#
# + Images are obtained directly from  torchvision.datasets.CIFAR10(args)
#
# + The notebook shows how to implement in Pytorch Lecunn's LeNet from scratch.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
torch.use_deterministic_algorithms(True)

from torchviz import make_dot

# %%
# Training settings
description = 'LeNet from scrarch in PyTorch, isng CIFAR-10 Data'
batch_size = 64
test_batch_size = 1000
epochs = 14
lr = 1.0
gamma = 0.7
no_cuda = False
no_mps = False
dry_run = False
seed = 1
log_interval = 10
save_model = False

# %%
def count_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("GPU is available!")
    print("Device name:", torch.cuda.get_device_name(0)) #Optional to print the GPU name.
else:
    device = torch.device("cpu")
    print("GPU is not available, using CPU instead.")
# Out:
# GPU is available!
# Device name: NVIDIA GeForce RTX 3060

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        # 3 input image channel, 6 output
        # feature maps and 5x5 conv kernel
        self.cn1 = nn.Conv2d(3, 6, 5)
        # 6 input image channel, 16 output
        # feature maps and 5x5 conv kernel
        self.cn2 = nn.Conv2d(6, 16, 5)
        # fully connected layers of size 120, 84 and 10
        # 5*5 is the spatial dimension at this layer
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
    def forward(self, x):
        # Convolution with 5x5 kernel
        x = F.relu(self.cn1(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Convolution with 5x5 kernel
        x = F.relu(self.cn2(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Flatten spatial and depth dimensions
        # into a single vector
        x = x.view(-1, self.flattened_features(x))
        # Fully connected operations
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


    def flattened_features(self, x):
        # all except the first (batch) dimension
        size = x.size()[1:]  
        num_feats = 1
        for s in size:
            num_feats *= s
        return num_feats

# Done defining LeNet
lenet = LeNet()
print(lenet)
model = lenet
# Out:
# LeNet(
#   (cn1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (cn2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
#x = torch.randn(1, 10)  # Dummy input
#y = model(x)
#dot = make_dot(y, params=dict(model.named_parameters()))
#dot.format = "png"
#dot.render("model_visualization") #this creates a model_visualization.png file.

# %%
 ## Load LeNet model to GPUS under the name "model" 
   
model = LeNet().to(device)    
print("This is LeNet Model in GPUs")
print(model)
print("LeNet Model params = ", count_params( model))
# Out:
# This is LeNet Model in GPUs
# LeNet(
#   (cn1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (cn2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )
# LeNet Model params =  62006

# %%
# Training settings

def train(net, trainloader, optim, epoch):
    # initialize loss
    loss_total = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        # ip refers to the input images, and ground_truth
        # refers to the output classes the images belong to
        ip, ground_truth = data
        # zero the parameter gradients
        optim.zero_grad()
        # forward-pass + backward-pass + optimization -step
        op = net(ip)
        loss = nn.CrossEntropyLoss()(op, ground_truth)
        loss.backward()
        optim.step()
        # update loss
        loss_total += loss.item()
        # print loss statistics
        if (i+1) % 1000 == 0:
            # print at the interval of 1000 mini-batches
            print('[Epoch number : %d, Mini-batches: %5d] \
                loss: %.3f' % (epoch + 1, i + 1,
                    loss_total / 200))
            loss_total = 0.0
 # end of train (args)

# %%
 # def test (args) 

def test(net, testloader):
    success = 0
    counter = 0
    with torch.no_grad():
        for data in testloader:
            im, ground_truth = data
            op = net(im)
            _, pred = torch.max(op.data, 1)
            counter += ground_truth.size(0)
            success += (pred == ground_truth).sum().item()
    print('LeNet accuracy on 10000 images from test dataset: %d %%'\
    % (100 * success / counter))

# endof def test(args)

# %%
# get the CIFAR-10 data from torchvision.datasets (args)

# The mean and std are kept as 0.5 for normalizing
# pixel values as the pixel values are originally
# in the range 0 to 1

train_transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, 4),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5),
                             (0.5, 0.5, 0.5))])
trainset = torchvision.datasets.CIFAR10(root='./data',
            train=True, download=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset,
        batch_size=8, shuffle=True)
test_transform = transforms.Compose([transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5),
                             (0.5, 0.5, 0.5))])
testset = torchvision.datasets.CIFAR10(root='./data',
            train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset,
        batch_size=10000, shuffle=False)

# ordering is important
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog',
'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
""" 
# trainloader and test_loader must have pin_memory = True

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2, pin_memory=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2, pin_memory=True)


"""
# Out:
# " \n# trainloader and test_loader must have pin_memory = True\n\ntransform = transforms.Compose(\n    [transforms.ToTensor(),\n     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])\n\ntrainset = torchvision.datasets.CIFAR10(root='./data', train=True,\n                                        download=True, transform=transform)\ntrainloader = torch.utils.data.DataLoader(trainset, batch_size=4,\n                                          shuffle=True, num_workers=2, pin_memory=True)\n\ntestset = torchvision.datasets.CIFAR10(root='./data', train=False,\n                                       download=True, transform=transform)\ntestloader = torch.utils.data.DataLoader(testset, batch_size=4,\n                                         shuffle=False, num_workers=2, pin_memory=True)\n\n\n"

# %%
## orderof classes is important
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog',
'frog', 'horse', 'ship', 'truck')

# %%
# define a function that displays an image
def imageshow(image):
    # un-normalize the image
    image = image/2 + 0.5
    npimage = image.numpy()
    plt.imshow(np.transpose(npimage, (1, 2, 0)))
    plt.show()

# sample images from training set
dataiter = iter(trainloader)
images, labels = next(dataiter)
# display images in a grid
num_images = 4
imageshow(torchvision.utils.make_grid(images[:num_images]))
# print labels
print(' ' + ' || '.join(classes[labels[j]]
         for j in range(num_images)))
# Out:
#  car || truck || cat || dog

# %%
# Training LeNet 

# define optimizer
optim = torch.optim.Adam(lenet.parameters(), lr=0.001)
# training loop over the dataset multiple times
for epoch in range(50):  
    train(lenet, trainloader, optim, epoch)
    print()
    test(lenet, testloader)


print("Finished Training ")
# Out:
# [Epoch number : 1, Mini-batches:  1000]                 loss: 9.898
# [Epoch number : 1, Mini-batches:  2000]                 loss: 8.788
# [Epoch number : 1, Mini-batches:  3000]                 loss: 8.463
# [Epoch number : 1, Mini-batches:  4000]                 loss: 8.168
# [Epoch number : 1, Mini-batches:  5000]                 loss: 8.066
# [Epoch number : 1, Mini-batches:  6000]                 loss: 7.807
#
# LeNet accuracy on 10000 images from test dataset: 45 %
# [Epoch number : 2, Mini-batches:  1000]                 loss: 7.607
# [Epoch number : 2, Mini-batches:  2000]                 loss: 7.562
# [Epoch number : 2, Mini-batches:  3000]                 loss: 7.389
# [Epoch number : 2, Mini-batches:  4000]                 loss: 7.390
# [Epoch number : 2, Mini-batches:  5000]                 loss: 7.274
# [Epoch number : 2, Mini-batches:  6000]                 loss: 7.176
#
# LeNet accuracy on 10000 images from test dataset: 50 %
# [Epoch number : 3, Mini-batches:  1000]                 loss: 7.130
# [Epoch number : 3, Mini-batches:  2000]                 loss: 7.231
# [Epoch number : 3, Mini-batches:  3000]                 loss: 6.904
# [Epoch number : 3, Mini-batches:  4000]                 loss: 6.931
# [Epoch number : 3, Mini-batches:  5000]                 loss: 6.938
# [Epoch number : 3, Mini-batches:  6000]                 loss: 6.808
#
# LeNet accuracy on 10000 images from test dataset: 53 %
# [Epoch number : 4, Mini-batches:  1000]                 loss: 6.936
# [Epoch number : 4, Mini-batches:  2000]                 loss: 6.646
# [Epoch number : 4, Mini-batches:  3000]                 loss: 6.764
# [Epoch number : 4, Mini-batches:  4000]                 loss: 6.682
# [Epoch number : 4, Mini-batches:  5000]                 loss: 6.616
# [Epoch number : 4, Mini-batches:  6000]                 loss: 6.647
#
# LeNet accuracy on 10000 images from test dataset: 56 %
# [Epoch number : 5, Mini-batches:  1000]                 loss: 6.500
# [Epoch number : 5, Mini-batches:  2000]                 loss: 6.575
# [Epoch number : 5, Mini-batches:  3000]                 loss: 6.528
# [Epoch number : 5, Mini-batches:  4000]                 loss: 6.420
# [Epoch number : 5, Mini-batches:  5000]                 loss: 6.532
# [Epoch number : 5, Mini-batches:  6000]                 loss: 6.471
#
# LeNet accuracy on 10000 images from test dataset: 56 %
# [Epoch number : 6, Mini-batches:  1000]                 loss: 6.325
# [Epoch number : 6, Mini-batches:  2000]                 loss: 6.384
# [Epoch number : 6, Mini-batches:  3000]                 loss: 6.267
# [Epoch number : 6, Mini-batches:  4000]                 loss: 6.250
# [Epoch number : 6, Mini-batches:  5000]                 loss: 6.380
# [Epoch number : 6, Mini-batches:  6000]                 loss: 6.386
#
# LeNet accuracy on 10000 images from test dataset: 58 %
# [Epoch number : 7, Mini-batches:  1000]                 loss: 6.164
# [Epoch number : 7, Mini-batches:  2000]                 loss: 6.207
# [Epoch number : 7, Mini-batches:  3000]                 loss: 6.145
# [Epoch number : 7, Mini-batches:  4000]                 loss: 6.213
# [Epoch number : 7, Mini-batches:  5000]                 loss: 6.210
# [Epoch number : 7, Mini-batches:  6000]                 loss: 6.326
#
# LeNet accuracy on 10000 images from test dataset: 58 %
# [Epoch number : 8, Mini-batches:  1000]                 loss: 6.128
# [Epoch number : 8, Mini-batches:  2000]                 loss: 6.068
# [Epoch number : 8, Mini-batches:  3000]                 loss: 6.142
# [Epoch number : 8, Mini-batches:  4000]                 loss: 6.112
# [Epoch number : 8, Mini-batches:  5000]                 loss: 6.151
# [Epoch number : 8, Mini-batches:  6000]                 loss: 6.076
#
# LeNet accuracy on 10000 images from test dataset: 60 %
# [Epoch number : 9, Mini-batches:  1000]                 loss: 5.965
# [Epoch number : 9, Mini-batches:  2000]                 loss: 5.984
# [Epoch number : 9, Mini-batches:  3000]                 loss: 6.183
# [Epoch number : 9, Mini-batches:  4000]                 loss: 6.010
# [Epoch number : 9, Mini-batches:  5000]                 loss: 6.023
# [Epoch number : 9, Mini-batches:  6000]                 loss: 6.022
#
# LeNet accuracy on 10000 images from test dataset: 59 %
# [Epoch number : 10, Mini-batches:  1000]                 loss: 5.981
# [Epoch number : 10, Mini-batches:  2000]                 loss: 5.963
# [Epoch number : 10, Mini-batches:  3000]                 loss: 5.976
# [Epoch number : 10, Mini-batches:  4000]                 loss: 5.964
# [Epoch number : 10, Mini-batches:  5000]                 loss: 5.963
# [Epoch number : 10, Mini-batches:  6000]                 loss: 5.850
#
# LeNet accuracy on 10000 images from test dataset: 61 %
# [Epoch number : 11, Mini-batches:  1000]                 loss: 5.910
# [Epoch number : 11, Mini-batches:  2000]                 loss: 5.839
# [Epoch number : 11, Mini-batches:  3000]                 loss: 5.853
# [Epoch number : 11, Mini-batches:  4000]                 loss: 5.902
# [Epoch number : 11, Mini-batches:  5000]                 loss: 5.818
# [Epoch number : 11, Mini-batches:  6000]                 loss: 5.869
#
# LeNet accuracy on 10000 images from test dataset: 60 %
# [Epoch number : 12, Mini-batches:  1000]                 loss: 5.950
# [Epoch number : 12, Mini-batches:  2000]                 loss: 5.652
# [Epoch number : 12, Mini-batches:  3000]                 loss: 5.821
# [Epoch number : 12, Mini-batches:  4000]                 loss: 5.824
# [Epoch number : 12, Mini-batches:  5000]                 loss: 5.723
# [Epoch number : 12, Mini-batches:  6000]                 loss: 5.760
#
# LeNet accuracy on 10000 images from test dataset: 63 %
# [Epoch number : 13, Mini-batches:  1000]                 loss: 5.795
# [Epoch number : 13, Mini-batches:  2000]                 loss: 5.679
# [Epoch number : 13, Mini-batches:  3000]                 loss: 5.883
# [Epoch number : 13, Mini-batches:  4000]                 loss: 5.783
# [Epoch number : 13, Mini-batches:  5000]                 loss: 5.870
# [Epoch number : 13, Mini-batches:  6000]                 loss: 5.858
#
# LeNet accuracy on 10000 images from test dataset: 57 %
# [Epoch number : 14, Mini-batches:  1000]                 loss: 5.664
# [Epoch number : 14, Mini-batches:  2000]                 loss: 5.627
# [Epoch number : 14, Mini-batches:  3000]                 loss: 5.733
# [Epoch number : 14, Mini-batches:  4000]                 loss: 5.851
# [Epoch number : 14, Mini-batches:  5000]                 loss: 5.690
# [Epoch number : 14, Mini-batches:  6000]                 loss: 5.755
#
# LeNet accuracy on 10000 images from test dataset: 63 %
# [Epoch number : 15, Mini-batches:  1000]                 loss: 5.694
# [Epoch number : 15, Mini-batches:  2000]                 loss: 5.652
# [Epoch number : 15, Mini-batches:  3000]                 loss: 5.696
# [Epoch number : 15, Mini-batches:  4000]                 loss: 5.556
# [Epoch number : 15, Mini-batches:  5000]                 loss: 5.710
# [Epoch number : 15, Mini-batches:  6000]                 loss: 5.701
#
# LeNet accuracy on 10000 images from test dataset: 63 %
# [Epoch number : 16, Mini-batches:  1000]                 loss: 5.615
# [Epoch number : 16, Mini-batches:  2000]                 loss: 5.720
# [Epoch number : 16, Mini-batches:  3000]                 loss: 5.667
# [Epoch number : 16, Mini-batches:  4000]                 loss: 5.525
# [Epoch number : 16, Mini-batches:  5000]                 loss: 5.601
# [Epoch number : 16, Mini-batches:  6000]                 loss: 5.690
#
# LeNet accuracy on 10000 images from test dataset: 62 %
# [Epoch number : 17, Mini-batches:  1000]                 loss: 5.569
# [Epoch number : 17, Mini-batches:  2000]                 loss: 5.551
# [Epoch number : 17, Mini-batches:  3000]                 loss: 5.614
# [Epoch number : 17, Mini-batches:  4000]                 loss: 5.551
# [Epoch number : 17, Mini-batches:  5000]                 loss: 5.700
# [Epoch number : 17, Mini-batches:  6000]                 loss: 5.471
#
# LeNet accuracy on 10000 images from test dataset: 63 %
# [Epoch number : 18, Mini-batches:  1000]                 loss: 5.449
# [Epoch number : 18, Mini-batches:  2000]                 loss: 5.604
# [Epoch number : 18, Mini-batches:  3000]                 loss: 5.460
# [Epoch number : 18, Mini-batches:  4000]                 loss: 5.534
# [Epoch number : 18, Mini-batches:  5000]                 loss: 5.558
# [Epoch number : 18, Mini-batches:  6000]                 loss: 5.613
#
# LeNet accuracy on 10000 images from test dataset: 64 %
# [Epoch number : 19, Mini-batches:  1000]                 loss: 5.550
# [Epoch number : 19, Mini-batches:  2000]                 loss: 5.368
# [Epoch number : 19, Mini-batches:  3000]                 loss: 5.622
# [Epoch number : 19, Mini-batches:  4000]                 loss: 5.664
# [Epoch number : 19, Mini-batches:  5000]                 loss: 5.626
# [Epoch number : 19, Mini-batches:  6000]                 loss: 5.534
#
# LeNet accuracy on 10000 images from test dataset: 62 %
# [Epoch number : 20, Mini-batches:  1000]                 loss: 5.485
# [Epoch number : 20, Mini-batches:  2000]                 loss: 5.461
# [Epoch number : 20, Mini-batches:  3000]                 loss: 5.578
# [Epoch number : 20, Mini-batches:  4000]                 loss: 5.465
# [Epoch number : 20, Mini-batches:  5000]                 loss: 5.610
# [Epoch number : 20, Mini-batches:  6000]                 loss: 5.468
#
# LeNet accuracy on 10000 images from test dataset: 64 %
# [Epoch number : 21, Mini-batches:  1000]                 loss: 5.477
# [Epoch number : 21, Mini-batches:  2000]                 loss: 5.544
# [Epoch number : 21, Mini-batches:  3000]                 loss: 5.425
# [Epoch number : 21, Mini-batches:  4000]                 loss: 5.521
# [Epoch number : 21, Mini-batches:  5000]                 loss: 5.469
# [Epoch number : 21, Mini-batches:  6000]                 loss: 5.430
#
# LeNet accuracy on 10000 images from test dataset: 64 %
# [Epoch number : 22, Mini-batches:  1000]                 loss: 5.379
# [Epoch number : 22, Mini-batches:  2000]                 loss: 5.495
# [Epoch number : 22, Mini-batches:  3000]                 loss: 5.303
# [Epoch number : 22, Mini-batches:  4000]                 loss: 5.476
# [Epoch number : 22, Mini-batches:  5000]                 loss: 5.361
# [Epoch number : 22, Mini-batches:  6000]                 loss: 5.513
#
# LeNet accuracy on 10000 images from test dataset: 63 %
# [Epoch number : 23, Mini-batches:  1000]                 loss: 5.398
# [Epoch number : 23, Mini-batches:  2000]                 loss: 5.483
# [Epoch number : 23, Mini-batches:  3000]                 loss: 5.430
# [Epoch number : 23, Mini-batches:  4000]                 loss: 5.434
# [Epoch number : 23, Mini-batches:  5000]                 loss: 5.557
# [Epoch number : 23, Mini-batches:  6000]                 loss: 5.423
#
# LeNet accuracy on 10000 images from test dataset: 62 %
# [Epoch number : 24, Mini-batches:  1000]                 loss: 5.419
# [Epoch number : 24, Mini-batches:  2000]                 loss: 5.534
# [Epoch number : 24, Mini-batches:  3000]                 loss: 5.527
# [Epoch number : 24, Mini-batches:  4000]                 loss: 5.415
# [Epoch number : 24, Mini-batches:  5000]                 loss: 5.420
# [Epoch number : 24, Mini-batches:  6000]                 loss: 5.389
#
# LeNet accuracy on 10000 images from test dataset: 62 %
# [Epoch number : 25, Mini-batches:  1000]                 loss: 5.341
# [Epoch number : 25, Mini-batches:  2000]                 loss: 5.458
# [Epoch number : 25, Mini-batches:  3000]                 loss: 5.419
# [Epoch number : 25, Mini-batches:  4000]                 loss: 5.447
# [Epoch number : 25, Mini-batches:  5000]                 loss: 5.430
# [Epoch number : 25, Mini-batches:  6000]                 loss: 5.418
#
# LeNet accuracy on 10000 images from test dataset: 64 %
# [Epoch number : 26, Mini-batches:  1000]                 loss: 5.399
# [Epoch number : 26, Mini-batches:  2000]                 loss: 5.379
# [Epoch number : 26, Mini-batches:  3000]                 loss: 5.396
# [Epoch number : 26, Mini-batches:  4000]                 loss: 5.331
# [Epoch number : 26, Mini-batches:  5000]                 loss: 5.302
# [Epoch number : 26, Mini-batches:  6000]                 loss: 5.433
#
# LeNet accuracy on 10000 images from test dataset: 61 %
# [Epoch number : 27, Mini-batches:  1000]                 loss: 5.350
# [Epoch number : 27, Mini-batches:  2000]                 loss: 5.417
# [Epoch number : 27, Mini-batches:  3000]                 loss: 5.381
# [Epoch number : 27, Mini-batches:  4000]                 loss: 5.338
# [Epoch number : 27, Mini-batches:  5000]                 loss: 5.398
# [Epoch number : 27, Mini-batches:  6000]                 loss: 5.471
#
# LeNet accuracy on 10000 images from test dataset: 64 %
# [Epoch number : 28, Mini-batches:  1000]                 loss: 5.412
# [Epoch number : 28, Mini-batches:  2000]                 loss: 5.356
# [Epoch number : 28, Mini-batches:  3000]                 loss: 5.345
# [Epoch number : 28, Mini-batches:  4000]                 loss: 5.300
# [Epoch number : 28, Mini-batches:  5000]                 loss: 5.375
# [Epoch number : 28, Mini-batches:  6000]                 loss: 5.362
#
# LeNet accuracy on 10000 images from test dataset: 63 %
# [Epoch number : 29, Mini-batches:  1000]                 loss: 5.390
# [Epoch number : 29, Mini-batches:  2000]                 loss: 5.379
# [Epoch number : 29, Mini-batches:  3000]                 loss: 5.248
# [Epoch number : 29, Mini-batches:  4000]                 loss: 5.253
# [Epoch number : 29, Mini-batches:  5000]                 loss: 5.327
# [Epoch number : 29, Mini-batches:  6000]                 loss: 5.311
#
# LeNet accuracy on 10000 images from test dataset: 63 %
# [Epoch number : 30, Mini-batches:  1000]                 loss: 5.300
# [Epoch number : 30, Mini-batches:  2000]                 loss: 5.280
# [Epoch number : 30, Mini-batches:  3000]                 loss: 5.404
# [Epoch number : 30, Mini-batches:  4000]                 loss: 5.340
# [Epoch number : 30, Mini-batches:  5000]                 loss: 5.376
# [Epoch number : 30, Mini-batches:  6000]                 loss: 5.280
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 31, Mini-batches:  1000]                 loss: 5.279
# [Epoch number : 31, Mini-batches:  2000]                 loss: 5.295
# [Epoch number : 31, Mini-batches:  3000]                 loss: 5.417
# [Epoch number : 31, Mini-batches:  4000]                 loss: 5.281
# [Epoch number : 31, Mini-batches:  5000]                 loss: 5.214
# [Epoch number : 31, Mini-batches:  6000]                 loss: 5.314
#
# LeNet accuracy on 10000 images from test dataset: 64 %
# [Epoch number : 32, Mini-batches:  1000]                 loss: 5.298
# [Epoch number : 32, Mini-batches:  2000]                 loss: 5.205
# [Epoch number : 32, Mini-batches:  3000]                 loss: 5.310
# [Epoch number : 32, Mini-batches:  4000]                 loss: 5.292
# [Epoch number : 32, Mini-batches:  5000]                 loss: 5.375
# [Epoch number : 32, Mini-batches:  6000]                 loss: 5.231
#
# LeNet accuracy on 10000 images from test dataset: 64 %
# [Epoch number : 33, Mini-batches:  1000]                 loss: 5.207
# [Epoch number : 33, Mini-batches:  2000]                 loss: 5.362
# [Epoch number : 33, Mini-batches:  3000]                 loss: 5.230
# [Epoch number : 33, Mini-batches:  4000]                 loss: 5.328
# [Epoch number : 33, Mini-batches:  5000]                 loss: 5.182
# [Epoch number : 33, Mini-batches:  6000]                 loss: 5.311
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 34, Mini-batches:  1000]                 loss: 5.194
# [Epoch number : 34, Mini-batches:  2000]                 loss: 5.352
# [Epoch number : 34, Mini-batches:  3000]                 loss: 5.233
# [Epoch number : 34, Mini-batches:  4000]                 loss: 5.244
# [Epoch number : 34, Mini-batches:  5000]                 loss: 5.285
# [Epoch number : 34, Mini-batches:  6000]                 loss: 5.267
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 35, Mini-batches:  1000]                 loss: 5.253
# [Epoch number : 35, Mini-batches:  2000]                 loss: 5.233
# [Epoch number : 35, Mini-batches:  3000]                 loss: 5.318
# [Epoch number : 35, Mini-batches:  4000]                 loss: 5.309
# [Epoch number : 35, Mini-batches:  5000]                 loss: 5.142
# [Epoch number : 35, Mini-batches:  6000]                 loss: 5.332
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 36, Mini-batches:  1000]                 loss: 5.311
# [Epoch number : 36, Mini-batches:  2000]                 loss: 5.219
# [Epoch number : 36, Mini-batches:  3000]                 loss: 5.196
# [Epoch number : 36, Mini-batches:  4000]                 loss: 5.221
# [Epoch number : 36, Mini-batches:  5000]                 loss: 5.239
# [Epoch number : 36, Mini-batches:  6000]                 loss: 5.266
#
# LeNet accuracy on 10000 images from test dataset: 63 %
# [Epoch number : 37, Mini-batches:  1000]                 loss: 5.230
# [Epoch number : 37, Mini-batches:  2000]                 loss: 5.188
# [Epoch number : 37, Mini-batches:  3000]                 loss: 5.225
# [Epoch number : 37, Mini-batches:  4000]                 loss: 5.360
# [Epoch number : 37, Mini-batches:  5000]                 loss: 5.270
# [Epoch number : 37, Mini-batches:  6000]                 loss: 5.250
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 38, Mini-batches:  1000]                 loss: 5.198
# [Epoch number : 38, Mini-batches:  2000]                 loss: 5.291
# [Epoch number : 38, Mini-batches:  3000]                 loss: 5.238
# [Epoch number : 38, Mini-batches:  4000]                 loss: 5.280
# [Epoch number : 38, Mini-batches:  5000]                 loss: 5.191
# [Epoch number : 38, Mini-batches:  6000]                 loss: 5.231
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 39, Mini-batches:  1000]                 loss: 5.084
# [Epoch number : 39, Mini-batches:  2000]                 loss: 5.241
# [Epoch number : 39, Mini-batches:  3000]                 loss: 5.173
# [Epoch number : 39, Mini-batches:  4000]                 loss: 5.294
# [Epoch number : 39, Mini-batches:  5000]                 loss: 5.161
# [Epoch number : 39, Mini-batches:  6000]                 loss: 5.268
#
# LeNet accuracy on 10000 images from test dataset: 66 %
# [Epoch number : 40, Mini-batches:  1000]                 loss: 5.180
# [Epoch number : 40, Mini-batches:  2000]                 loss: 5.221
# [Epoch number : 40, Mini-batches:  3000]                 loss: 5.316
# [Epoch number : 40, Mini-batches:  4000]                 loss: 5.118
# [Epoch number : 40, Mini-batches:  5000]                 loss: 5.167
# [Epoch number : 40, Mini-batches:  6000]                 loss: 5.232
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 41, Mini-batches:  1000]                 loss: 5.139
# [Epoch number : 41, Mini-batches:  2000]                 loss: 5.182
# [Epoch number : 41, Mini-batches:  3000]                 loss: 5.161
# [Epoch number : 41, Mini-batches:  4000]                 loss: 5.297
# [Epoch number : 41, Mini-batches:  5000]                 loss: 5.150
# [Epoch number : 41, Mini-batches:  6000]                 loss: 5.236
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 42, Mini-batches:  1000]                 loss: 5.156
# [Epoch number : 42, Mini-batches:  2000]                 loss: 5.118
# [Epoch number : 42, Mini-batches:  3000]                 loss: 5.253
# [Epoch number : 42, Mini-batches:  4000]                 loss: 5.204
# [Epoch number : 42, Mini-batches:  5000]                 loss: 5.204
# [Epoch number : 42, Mini-batches:  6000]                 loss: 5.257
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 43, Mini-batches:  1000]                 loss: 5.195
# [Epoch number : 43, Mini-batches:  2000]                 loss: 5.142
# [Epoch number : 43, Mini-batches:  3000]                 loss: 5.236
# [Epoch number : 43, Mini-batches:  4000]                 loss: 5.164
# [Epoch number : 43, Mini-batches:  5000]                 loss: 5.260
# [Epoch number : 43, Mini-batches:  6000]                 loss: 4.964
#
# LeNet accuracy on 10000 images from test dataset: 66 %
# [Epoch number : 44, Mini-batches:  1000]                 loss: 5.248
# [Epoch number : 44, Mini-batches:  2000]                 loss: 5.254
# [Epoch number : 44, Mini-batches:  3000]                 loss: 5.104
# [Epoch number : 44, Mini-batches:  4000]                 loss: 5.107
# [Epoch number : 44, Mini-batches:  5000]                 loss: 5.328
# [Epoch number : 44, Mini-batches:  6000]                 loss: 5.161
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 45, Mini-batches:  1000]                 loss: 5.249
# [Epoch number : 45, Mini-batches:  2000]                 loss: 5.183
# [Epoch number : 45, Mini-batches:  3000]                 loss: 5.211
# [Epoch number : 45, Mini-batches:  4000]                 loss: 5.018
# [Epoch number : 45, Mini-batches:  5000]                 loss: 5.089
# [Epoch number : 45, Mini-batches:  6000]                 loss: 5.292
#
# LeNet accuracy on 10000 images from test dataset: 66 %
# [Epoch number : 46, Mini-batches:  1000]                 loss: 5.211
# [Epoch number : 46, Mini-batches:  2000]                 loss: 5.219
# [Epoch number : 46, Mini-batches:  3000]                 loss: 5.137
# [Epoch number : 46, Mini-batches:  4000]                 loss: 5.127
# [Epoch number : 46, Mini-batches:  5000]                 loss: 5.080
# [Epoch number : 46, Mini-batches:  6000]                 loss: 5.192
#
# LeNet accuracy on 10000 images from test dataset: 67 %
# [Epoch number : 47, Mini-batches:  1000]                 loss: 5.143
# [Epoch number : 47, Mini-batches:  2000]                 loss: 5.146
# [Epoch number : 47, Mini-batches:  3000]                 loss: 5.137
# [Epoch number : 47, Mini-batches:  4000]                 loss: 5.107
# [Epoch number : 47, Mini-batches:  5000]                 loss: 5.131
# [Epoch number : 47, Mini-batches:  6000]                 loss: 5.340
#
# LeNet accuracy on 10000 images from test dataset: 66 %
# [Epoch number : 48, Mini-batches:  1000]                 loss: 5.251
# [Epoch number : 48, Mini-batches:  2000]                 loss: 5.029
# [Epoch number : 48, Mini-batches:  3000]                 loss: 5.127
# [Epoch number : 48, Mini-batches:  4000]                 loss: 5.166
# [Epoch number : 48, Mini-batches:  5000]                 loss: 5.157
# [Epoch number : 48, Mini-batches:  6000]                 loss: 5.215
#
# LeNet accuracy on 10000 images from test dataset: 65 %
# [Epoch number : 49, Mini-batches:  1000]                 loss: 5.091
# [Epoch number : 49, Mini-batches:  2000]                 loss: 5.246
# [Epoch number : 49, Mini-batches:  3000]                 loss: 5.014
# [Epoch number : 49, Mini-batches:  4000]                 loss: 5.026
# [Epoch number : 49, Mini-batches:  5000]                 loss: 5.071
# [Epoch number : 49, Mini-batches:  6000]                 loss: 5.226
#
# LeNet accuracy on 10000 images from test dataset: 66 %
# [Epoch number : 50, Mini-batches:  1000]                 loss: 5.121
# [Epoch number : 50, Mini-batches:  2000]                 loss: 5.072
# [Epoch number : 50, Mini-batches:  3000]                 loss: 5.089
# [Epoch number : 50, Mini-batches:  4000]                 loss: 5.164
# [Epoch number : 50, Mini-batches:  5000]                 loss: 5.074
# [Epoch number : 50, Mini-batches:  6000]                 loss: 5.017
#
# LeNet accuracy on 10000 images from test dataset: 66 %
# Finished Training

# %%
## Save the model to disk 

modelPath = '/drv3/hm3/code/python/torch/'
modelName = modelPath + "LeNet_Cifar10.pth"
torch.save(lenet.state_dict(), modelName)

# %%
# load test dataset images
d_iter = iter(testloader)
im, ground_truth = next(d_iter)
# print images and ground truth
imageshow(torchvision.utils.make_grid(im[:4]))
print('Label:  ', ' '.join('%5s' %
            classes[ground_truth[j]]
            for j in range(4)))

# load model
lenet_cached = LeNet()
lenet_cached.load_state_dict(torch.load(modelName))
# model inference
op = lenet_cached(im)
# print predictions
_, pred = torch.max(op, 1)
print('Prediction: ', ' '.join('%5s' % classes[pred[j]]
                        for j in range(4)))
# Out:
# Label:     cat  ship  ship plane
# Prediction:    cat  ship  ship   car
# /tmp/ipykernel_10980/953884977.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   lenet_cached.load_state_dict(torch.load(modelName))

# %%
# Eval MODEL accuracy 

success = 0
counter = 0
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op.data, 1)
        counter += ground_truth.size(0)
        success += (pred == ground_truth).sum().item()
print('Model accuracy on 10000 images from test dataset: %d %%'\
            % (100 * success / counter))
# Out:
# Model accuracy on 10000 images from test dataset: 66 %

# %%
## EVal per-class accuracy 

class_sucess = list(0. for i in range(10))
class_counter = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op, 1)
        c = (pred == ground_truth).squeeze()
        for i in range(10000):
            ground_truth_curr = ground_truth[i]
            class_sucess[ground_truth_curr] += c[i].item()
            class_counter[ground_truth_curr] += 1
for i in range(10):
    print('Model accuracy for class %5s : %2d %%' % (
            classes[i], 100 * class_sucess[i] / class_counter[i]))
# Out:
# Model accuracy for class plane : 66 %
# Model accuracy for class   car : 78 %
# Model accuracy for class  bird : 49 %
# Model accuracy for class   cat : 48 %
# Model accuracy for class  deer : 50 %
# Model accuracy for class   dog : 57 %
# Model accuracy for class  frog : 78 %
# Model accuracy for class horse : 75 %
# Model accuracy for class  ship : 78 %
# Model accuracy for class truck : 84 %
