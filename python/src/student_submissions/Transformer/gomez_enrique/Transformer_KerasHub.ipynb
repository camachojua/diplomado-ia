# %% [markdown]
# # English-to-Spanish translation with KerasHub
#
# **Author:** [Abheesht Sharma](https://github.com/abheesht17/)<br>
# **Date created:** 2022/05/26<br>
# **Last modified:** 2024/04/30<br>
# **Description:** Use KerasHub to train a sequence-to-sequence Transformer model on the machine translation task.

# %% [markdown]
# ## Introduction
#
# KerasHub provides building blocks for NLP (model layers, tokenizers, metrics, etc.) and
# makes it convenient to construct NLP pipelines.
#
# In this example, we'll use KerasHub layers to build an encoder-decoder Transformer
# model, and train it on the English-to-Spanish machine translation task.
#
# This example is based on the
# [English-to-Spanish NMT
# example](https://keras.io/examples/nlp/neural_machine_translation_with_transformer/)
# by [fchollet](https://twitter.com/fchollet). The original example is more low-level
# and implements layers from scratch, whereas this example uses KerasHub to show
# some more advanced approaches, such as subword tokenization and using metrics
# to compute the quality of generated translations.
#
# You'll learn how to:
#
# - Tokenize text using `keras_hub.tokenizers.WordPieceTokenizer`.
# - Implement a sequence-to-sequence Transformer model using KerasHub's
# `keras_hub.layers.TransformerEncoder`, `keras_hub.layers.TransformerDecoder` and
# `keras_hub.layers.TokenAndPositionEmbedding` layers, and train it.
# - Use `keras_hub.samplers` to generate translations of unseen input sentences
#  using the top-p decoding strategy!
#
# Don't worry if you aren't familiar with KerasHub. This tutorial will start with
# the basics. Let's dive right in!

# %% [markdown]
# ## Setup
#
# Before we start implementing the pipeline, let's import all the libraries we need.

# %%
# !pip install -q --upgrade rouge-score
# !pip install -q --upgrade keras-hub
# !pip install -q --upgrade keras  # Upgrade to Keras 3.

# %%
import keras_hub
import pathlib
import random

import keras
from keras import ops

import tensorflow.data as tf_data
from tensorflow_text.tools.wordpiece_vocab import (
    bert_vocab_from_dataset as bert_vocab,
)

# %% [markdown]
# Let's also define our parameters/hyperparameters.

# %%
BATCH_SIZE = 64
EPOCHS = 100  # This should be at least 10 for convergence
MAX_SEQUENCE_LENGTH = 20
ENG_VOCAB_SIZE = 20000
SPA_VOCAB_SIZE = 20000

EMBED_DIM = 256
INTERMEDIATE_DIM = 2048
NUM_HEADS = 8

# %% [markdown]
# ## Downloading the data
#
# We'll be working with an English-to-Spanish translation dataset
# provided by [Anki](https://www.manythings.org/anki/). Let's download it:

# %%
from google.colab import drive

drive.mount('/content/drive')
text_file = '/content/drive/MyDrive/Colab Notebooks/corpus/spa.txt'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Parsing the data
#
# Each line contains an English sentence and its corresponding Spanish sentence.
# The English sentence is the *source sequence* and Spanish one is the *target sequence*.
# Before adding the text to a list, we convert it to lowercase.

# %%
with open(text_file) as f:
    lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
    eng, spa = line.split("\t")
    eng = eng.lower()
    spa = spa.lower()
    text_pairs.append((eng, spa))

# %% [markdown]
# Here's what our sentence pairs look like:

# %%
for _ in range(5):
    print(random.choice(text_pairs))
# Out:
# ('most students like sports.', 'a la mayoría de los estudiantes les gustan los deportes.')
# ('he always borrows money from me.', 'él siempre me pide dinero prestado.')
# ("i'd like to send my dress to a dry cleaner.", 'me gustaría enviar mi vestido a una tintorería.')
# ('you lack imagination.', 'te falta imaginación.')
# ('i saw tom in the mirror so i turned around and said hi.', 'vi a tom reflejado en el espejo, así que le dije hola.')

# %% [markdown]
# Now, let's split the sentence pairs into a training set, a validation set,
# and a test set.

# %%
random.shuffle(text_pairs)
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples
train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples : num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples :]

print(f"{len(text_pairs)} total pairs")
print(f"{len(train_pairs)} training pairs")
print(f"{len(val_pairs)} validation pairs")
print(f"{len(test_pairs)} test pairs")
# Out:
# 141543 total pairs
# 99081 training pairs
# 21231 validation pairs
# 21231 test pairs

# %% [markdown]
# ## Tokenizing the data
#
# We'll define two tokenizers - one for the source language (English), and the other
# for the target language (Spanish). We'll be using
# `keras_hub.tokenizers.WordPieceTokenizer` to tokenize the text.
# `keras_hub.tokenizers.WordPieceTokenizer` takes a WordPiece vocabulary
# and has functions for tokenizing the text, and detokenizing sequences of tokens.
#
# Before we define the two tokenizers, we first need to train them on the dataset
# we have. The WordPiece tokenization algorithm is a subword tokenization algorithm;
# training it on a corpus gives us a vocabulary of subwords. A subword tokenizer
# is a compromise between word tokenizers (word tokenizers need very large
# vocabularies for good coverage of input words), and character tokenizers
# (characters don't really encode meaning like words do). Luckily, KerasHub
# makes it very simple to train WordPiece on a corpus with the
# `keras_hub.tokenizers.compute_word_piece_vocabulary` utility.

# %%
def train_word_piece(text_samples, vocab_size, reserved_tokens):
    word_piece_ds = tf_data.Dataset.from_tensor_slices(text_samples)
    vocab = keras_hub.tokenizers.compute_word_piece_vocabulary(
        word_piece_ds.batch(1000).prefetch(2),
        vocabulary_size=vocab_size,
        reserved_tokens=reserved_tokens,
    )
    return vocab

# %% [markdown]
# Every vocabulary has a few special, reserved tokens. We have four such tokens:
#
# - `"[PAD]"` - Padding token. Padding tokens are appended to the input sequence
# length when the input sequence length is shorter than the maximum sequence length.
# - `"[UNK]"` - Unknown token.
# - `"[START]"` - Token that marks the start of the input sequence.
# - `"[END]"` - Token that marks the end of the input sequence.

# %%
reserved_tokens = ["[PAD]", "[UNK]", "[START]", "[END]"]

eng_samples = [text_pair[0] for text_pair in train_pairs]
eng_vocab = train_word_piece(eng_samples, ENG_VOCAB_SIZE, reserved_tokens)

spa_samples = [text_pair[1] for text_pair in train_pairs]
spa_vocab = train_word_piece(spa_samples, SPA_VOCAB_SIZE, reserved_tokens)

# %% [markdown]
# Let's see some tokens!

# %%
print("English Tokens: ", eng_vocab[100:110])
print("Spanish Tokens: ", spa_vocab[100:110])
# Out:
# English Tokens:  ['go', 'him', 'll', 'they', 'how', 'has', 'did', 'her', 'time', 'as']
# Spanish Tokens:  ['ella', 'las', 'más', 'al', 'yo', 'eso', 'tu', 'estoy', 'muy', 'esta']

# %% [markdown]
# Now, let's define the tokenizers. We will configure the tokenizers with the
# the vocabularies trained above.

# %%
eng_tokenizer = keras_hub.tokenizers.WordPieceTokenizer(
    vocabulary=eng_vocab, lowercase=False
)
spa_tokenizer = keras_hub.tokenizers.WordPieceTokenizer(
    vocabulary=spa_vocab, lowercase=False
)

# %% [markdown]
# Let's try and tokenize a sample from our dataset! To verify whether the text has
# been tokenized correctly, we can also detokenize the list of tokens back to the
# original text.

# %%
eng_input_ex = text_pairs[0][0]
eng_tokens_ex = eng_tokenizer.tokenize(eng_input_ex)
print("English sentence: ", eng_input_ex)
print("Tokens: ", eng_tokens_ex)
print(
    "Recovered text after detokenizing: ",
    eng_tokenizer.detokenize(eng_tokens_ex),
)

print()

spa_input_ex = text_pairs[0][1]
spa_tokens_ex = spa_tokenizer.tokenize(spa_input_ex)
print("Spanish sentence: ", spa_input_ex)
print("Tokens: ", spa_tokens_ex)
print(
    "Recovered text after detokenizing: ",
    spa_tokenizer.detokenize(spa_tokens_ex),
)
# Out:
# English sentence:  i pretended that i didn't know tom.
# Tokens:  tf.Tensor([  34 1463   69   34  112    8   45   94   65   11], shape=(10,), dtype=int32)
# Recovered text after detokenizing:  i pretended that i didn ' t know tom .
#
# Spanish sentence:  hice como si no conociera a tom.
# Tokens:  tf.Tensor([ 409  122  115   76   93  302 1632   28   77   13], shape=(10,), dtype=int32)
# Recovered text after detokenizing:  hice como si no conociera a tom .

# %% [markdown]
# ## Format datasets
#
# Next, we'll format our datasets.
#
# At each training step, the model will seek to predict target words N+1 (and beyond)
# using the source sentence and the target words 0 to N.
#
# As such, the training dataset will yield a tuple `(inputs, targets)`, where:
#
# - `inputs` is a dictionary with the keys `encoder_inputs` and `decoder_inputs`.
# `encoder_inputs` is the tokenized source sentence and `decoder_inputs` is the target
# sentence "so far",
# that is to say, the words 0 to N used to predict word N+1 (and beyond) in the target
# sentence.
# - `target` is the target sentence offset by one step:
# it provides the next words in the target sentence -- what the model will try to predict.
#
# We will add special tokens, `"[START]"` and `"[END]"`, to the input Spanish
# sentence after tokenizing the text. We will also pad the input to a fixed length.
# This can be easily done using `keras_hub.layers.StartEndPacker`.

# %%
def preprocess_batch(eng, spa):
    batch_size = ops.shape(spa)[0]

    eng = eng_tokenizer(eng)
    spa = spa_tokenizer(spa)

    # Pad `eng` to `MAX_SEQUENCE_LENGTH`.
    eng_start_end_packer = keras_hub.layers.StartEndPacker(
        sequence_length=MAX_SEQUENCE_LENGTH,
        pad_value=eng_tokenizer.token_to_id("[PAD]"),
    )
    eng = eng_start_end_packer(eng)

    # Add special tokens (`"[START]"` and `"[END]"`) to `spa` and pad it as well.
    spa_start_end_packer = keras_hub.layers.StartEndPacker(
        sequence_length=MAX_SEQUENCE_LENGTH + 1,
        start_value=spa_tokenizer.token_to_id("[START]"),
        end_value=spa_tokenizer.token_to_id("[END]"),
        pad_value=spa_tokenizer.token_to_id("[PAD]"),
    )
    spa = spa_start_end_packer(spa)

    return (
        {
            "encoder_inputs": eng,
            "decoder_inputs": spa[:, :-1],
        },
        spa[:, 1:],
    )


def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf_data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.map(preprocess_batch, num_parallel_calls=tf_data.AUTOTUNE)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %% [markdown]
# Let's take a quick look at the sequence shapes
# (we have batches of 64 pairs, and all sequences are 40 steps long):

# %%
for inputs, targets in train_ds.take(1):
    print(f'inputs["encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs["encoder_inputs"].shape: (64, 20)
# inputs["decoder_inputs"].shape: (64, 20)
# targets.shape: (64, 20)

# %% [markdown]
# ## Building the model
#
# Now, let's move on to the exciting part - defining our model!
# We first need an embedding layer, i.e., a vector for every token in our input sequence.
# This embedding layer can be initialised randomly. We also need a positional
# embedding layer which encodes the word order in the sequence. The convention is
# to add these two embeddings. KerasHub has a `keras_hub.layers.TokenAndPositionEmbedding `
# layer which does all of the above steps for us.
#
# Our sequence-to-sequence Transformer consists of a `keras_hub.layers.TransformerEncoder`
# layer and a `keras_hub.layers.TransformerDecoder` layer chained together.
#
# The source sequence will be passed to `keras_hub.layers.TransformerEncoder`, which
# will produce a new representation of it. This new representation will then be passed
# to the `keras_hub.layers.TransformerDecoder`, together with the target sequence
# so far (target words 0 to N). The `keras_hub.layers.TransformerDecoder` will
# then seek to predict the next words in the target sequence (N+1 and beyond).
#
# A key detail that makes this possible is causal masking.
# The `keras_hub.layers.TransformerDecoder` sees the entire sequence at once, and
# thus we must make sure that it only uses information from target tokens 0 to N
# when predicting token N+1 (otherwise, it could use information from the future,
# which would result in a model that cannot be used at inference time). Causal masking
# is enabled by default in `keras_hub.layers.TransformerDecoder`.
#
# We also need to mask the padding tokens (`"[PAD]"`). For this, we can set the
# `mask_zero` argument of the `keras_hub.layers.TokenAndPositionEmbedding` layer
# to True. This will then be propagated to all subsequent layers.

# %%
# Encoder
encoder_inputs = keras.Input(shape=(None,), name="encoder_inputs")

x = keras_hub.layers.TokenAndPositionEmbedding(
    vocabulary_size=ENG_VOCAB_SIZE,
    sequence_length=MAX_SEQUENCE_LENGTH,
    embedding_dim=EMBED_DIM,
)(encoder_inputs)

encoder_outputs = keras_hub.layers.TransformerEncoder(
    intermediate_dim=INTERMEDIATE_DIM, num_heads=NUM_HEADS
)(inputs=x)
encoder = keras.Model(encoder_inputs, encoder_outputs)


# Decoder
decoder_inputs = keras.Input(shape=(None,), name="decoder_inputs")
encoded_seq_inputs = keras.Input(shape=(None, EMBED_DIM), name="decoder_state_inputs")

x = keras_hub.layers.TokenAndPositionEmbedding(
    vocabulary_size=SPA_VOCAB_SIZE,
    sequence_length=MAX_SEQUENCE_LENGTH,
    embedding_dim=EMBED_DIM,
)(decoder_inputs)

x = keras_hub.layers.TransformerDecoder(
    intermediate_dim=INTERMEDIATE_DIM, num_heads=NUM_HEADS
)(decoder_sequence=x, encoder_sequence=encoded_seq_inputs)
x = keras.layers.Dropout(0.5)(x)
decoder_outputs = keras.layers.Dense(SPA_VOCAB_SIZE, activation="softmax")(x)
decoder = keras.Model(
    [
        decoder_inputs,
        encoded_seq_inputs,
    ],
    decoder_outputs,
)
decoder_outputs = decoder([decoder_inputs, encoder_outputs])

transformer = keras.Model(
    [encoder_inputs, decoder_inputs],
    decoder_outputs,
    name="transformer",
)

# %% [markdown]
# ## Training our model
#
# We'll use accuracy as a quick way to monitor training progress on the validation data.
# Note that machine translation typically uses BLEU scores as well as other metrics,
# rather than accuracy. However, in order to use metrics like ROUGE, BLEU, etc. we
# will have decode the probabilities and generate the text. Text generation is
# computationally expensive, and performing this during training is not recommended.
#
# Here we only train for 1 epoch, but to get the model to actually converge
# you should train for at least 10 epochs.

# %%
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint

transformer.summary()
transformer.compile(
    "rmsprop",
   loss=keras.losses.SparseCategoricalCrossentropy(ignore_class=0),
    metrics=["accuracy"]
)

# csv logger callback
csv_logger = CSVLogger("/content/drive/MyDrive/Colab Notebooks/transformer.training.log")

# model checkpoint callback
model_checkpoint = ModelCheckpoint(
    filepath="/content/drive/MyDrive/Colab Notebooks/transformer.checkpoint.keras",
    monitor="val_accuracy",
    mode="max",
    save_best_only=True,
)
transformer.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=val_ds,
    verbose=2,
    callbacks=[csv_logger, model_checkpoint],
)
# Out:
# Model: "transformer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ token_and_position_embed… │ (None, None, 256)      │      5,125,120 │ encoder_inputs[0][0]   │
# │ (TokenAndPositionEmbeddi… │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_inputs            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder       │ (None, None, 256)      │      1,315,072 │ token_and_position_em… │
# │ (TransformerEncoder)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional_1 (Functional) │ (None, None, 20000)    │     11,843,872 │ decoder_inputs[0][0],  │
# │                           │                        │                │ transformer_encoder[0… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 18,284,064 (69.75 MB)
#  Trainable params: 18,284,064 (69.75 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 1549/1549 - 85s - 55ms/step - accuracy: 0.1851 - loss: 4.0011 - val_accuracy: 0.2449 - val_loss: 2.9349
# Epoch 2/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.2545 - loss: 2.7890 - val_accuracy: 0.2737 - val_loss: 2.4799
# Epoch 3/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.2765 - loss: 2.4401 - val_accuracy: 0.2872 - val_loss: 2.2819
# Epoch 4/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.2894 - loss: 2.2596 - val_accuracy: 0.2956 - val_loss: 2.2095
# Epoch 5/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.2985 - loss: 2.1386 - val_accuracy: 0.2989 - val_loss: 2.1730
# Epoch 6/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3049 - loss: 2.0588 - val_accuracy: 0.3022 - val_loss: 2.1566
# Epoch 7/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3098 - loss: 1.9968 - val_accuracy: 0.3022 - val_loss: 2.1590
# Epoch 8/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3142 - loss: 1.9410 - val_accuracy: 0.3043 - val_loss: 2.1568
# Epoch 9/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3176 - loss: 1.8962 - val_accuracy: 0.3062 - val_loss: 2.1653
# Epoch 10/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3210 - loss: 1.8535 - val_accuracy: 0.3068 - val_loss: 2.1828
# Epoch 11/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.3240 - loss: 1.8126 - val_accuracy: 0.3076 - val_loss: 2.1721
# Epoch 12/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.3268 - loss: 1.7757 - val_accuracy: 0.3081 - val_loss: 2.1710
# Epoch 13/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3291 - loss: 1.7445 - val_accuracy: 0.3078 - val_loss: 2.1887
# Epoch 14/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.3315 - loss: 1.7128 - val_accuracy: 0.3082 - val_loss: 2.1991
# Epoch 15/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.3337 - loss: 1.6834 - val_accuracy: 0.3085 - val_loss: 2.2051
# Epoch 16/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.3361 - loss: 1.6532 - val_accuracy: 0.3087 - val_loss: 2.2339
# Epoch 17/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.3380 - loss: 1.6288 - val_accuracy: 0.3096 - val_loss: 2.2381
# Epoch 18/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3401 - loss: 1.6013 - val_accuracy: 0.3084 - val_loss: 2.2566
# Epoch 19/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.3419 - loss: 1.5781 - val_accuracy: 0.3103 - val_loss: 2.2564
# Epoch 20/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3434 - loss: 1.5589 - val_accuracy: 0.3084 - val_loss: 2.2797
# Epoch 21/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3450 - loss: 1.5362 - val_accuracy: 0.3103 - val_loss: 2.3038
# Epoch 22/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3467 - loss: 1.5155 - val_accuracy: 0.3091 - val_loss: 2.3247
# Epoch 23/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3482 - loss: 1.4981 - val_accuracy: 0.3101 - val_loss: 2.3123
# Epoch 24/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.3495 - loss: 1.4800 - val_accuracy: 0.3105 - val_loss: 2.3372
# Epoch 25/100
# 1549/1549 - 19s - 12ms/step - accuracy: 0.3508 - loss: 1.4647 - val_accuracy: 0.3103 - val_loss: 2.3366
# Epoch 26/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3523 - loss: 1.4461 - val_accuracy: 0.3117 - val_loss: 2.3478
# Epoch 27/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3535 - loss: 1.4306 - val_accuracy: 0.3109 - val_loss: 2.3634
# Epoch 28/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3546 - loss: 1.4165 - val_accuracy: 0.3111 - val_loss: 2.3528
# Epoch 29/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3558 - loss: 1.3997 - val_accuracy: 0.3102 - val_loss: 2.3892
# Epoch 30/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3569 - loss: 1.3890 - val_accuracy: 0.3102 - val_loss: 2.3999
# Epoch 31/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3579 - loss: 1.3761 - val_accuracy: 0.3101 - val_loss: 2.4106
# Epoch 32/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3588 - loss: 1.3646 - val_accuracy: 0.3114 - val_loss: 2.4025
# Epoch 33/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3598 - loss: 1.3511 - val_accuracy: 0.3104 - val_loss: 2.4481
# Epoch 34/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3607 - loss: 1.3422 - val_accuracy: 0.3093 - val_loss: 2.4562
# Epoch 35/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3614 - loss: 1.3322 - val_accuracy: 0.3108 - val_loss: 2.4745
# Epoch 36/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3625 - loss: 1.3206 - val_accuracy: 0.3107 - val_loss: 2.4977
# Epoch 37/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3631 - loss: 1.3114 - val_accuracy: 0.3077 - val_loss: 2.5396
# Epoch 38/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3641 - loss: 1.2996 - val_accuracy: 0.3086 - val_loss: 2.5444
# Epoch 39/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3646 - loss: 1.2944 - val_accuracy: 0.3101 - val_loss: 2.5336
# Epoch 40/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3654 - loss: 1.2840 - val_accuracy: 0.3098 - val_loss: 2.5365
# Epoch 41/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3661 - loss: 1.2730 - val_accuracy: 0.3103 - val_loss: 2.5590
# Epoch 42/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3668 - loss: 1.2653 - val_accuracy: 0.3113 - val_loss: 2.5511
# Epoch 43/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3675 - loss: 1.2586 - val_accuracy: 0.3111 - val_loss: 2.5559
# Epoch 44/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3679 - loss: 1.2518 - val_accuracy: 0.3095 - val_loss: 2.5804
# Epoch 45/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3688 - loss: 1.2427 - val_accuracy: 0.3090 - val_loss: 2.6138
# Epoch 46/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3694 - loss: 1.2346 - val_accuracy: 0.3097 - val_loss: 2.6454
# Epoch 47/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3701 - loss: 1.2269 - val_accuracy: 0.3104 - val_loss: 2.6268
# Epoch 48/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3705 - loss: 1.2188 - val_accuracy: 0.3095 - val_loss: 2.6449
# Epoch 49/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3711 - loss: 1.2132 - val_accuracy: 0.3096 - val_loss: 2.6556
# Epoch 50/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3716 - loss: 1.2096 - val_accuracy: 0.3104 - val_loss: 2.6407
# Epoch 51/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3721 - loss: 1.2019 - val_accuracy: 0.3103 - val_loss: 2.6865
# Epoch 52/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3728 - loss: 1.1954 - val_accuracy: 0.3093 - val_loss: 2.6873
# Epoch 53/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3730 - loss: 1.1911 - val_accuracy: 0.3101 - val_loss: 2.6763
# Epoch 54/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3739 - loss: 1.1832 - val_accuracy: 0.3098 - val_loss: 2.7139
# Epoch 55/100
# 1549/1549 - 21s - 13ms/step - accuracy: 0.3743 - loss: 1.1782 - val_accuracy: 0.3119 - val_loss: 2.6919
# Epoch 56/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3746 - loss: 1.1715 - val_accuracy: 0.3107 - val_loss: 2.6922
# Epoch 57/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3748 - loss: 1.1681 - val_accuracy: 0.3088 - val_loss: 2.7800
# Epoch 58/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3756 - loss: 1.1632 - val_accuracy: 0.3098 - val_loss: 2.7649
# Epoch 59/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3760 - loss: 1.1552 - val_accuracy: 0.3107 - val_loss: 2.7457
# Epoch 60/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3765 - loss: 1.1525 - val_accuracy: 0.3108 - val_loss: 2.7398
# Epoch 61/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3769 - loss: 1.1467 - val_accuracy: 0.3082 - val_loss: 2.8089
# Epoch 62/100
# 1549/1549 - 19s - 12ms/step - accuracy: 0.3769 - loss: 1.1454 - val_accuracy: 0.3088 - val_loss: 2.7925
# Epoch 63/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3773 - loss: 1.1404 - val_accuracy: 0.3104 - val_loss: 2.7613
# Epoch 64/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3777 - loss: 1.1344 - val_accuracy: 0.3101 - val_loss: 2.8053
# Epoch 65/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3781 - loss: 1.1299 - val_accuracy: 0.3111 - val_loss: 2.7923
# Epoch 66/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3786 - loss: 1.1274 - val_accuracy: 0.3099 - val_loss: 2.8268
# Epoch 67/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3789 - loss: 1.1222 - val_accuracy: 0.3097 - val_loss: 2.8121
# Epoch 68/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3793 - loss: 1.1174 - val_accuracy: 0.3101 - val_loss: 2.7957
# Epoch 69/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3793 - loss: 1.1157 - val_accuracy: 0.3077 - val_loss: 2.8710
# Epoch 70/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3797 - loss: 1.1132 - val_accuracy: 0.3086 - val_loss: 2.8422
# Epoch 71/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3800 - loss: 1.1081 - val_accuracy: 0.3091 - val_loss: 2.8918
# Epoch 72/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3804 - loss: 1.1054 - val_accuracy: 0.3103 - val_loss: 2.8841
# Epoch 73/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3807 - loss: 1.1022 - val_accuracy: 0.3106 - val_loss: 2.8573
# Epoch 74/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3810 - loss: 1.0986 - val_accuracy: 0.3080 - val_loss: 2.9000
# Epoch 75/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3809 - loss: 1.0982 - val_accuracy: 0.3094 - val_loss: 2.9284
# Epoch 76/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3814 - loss: 1.0936 - val_accuracy: 0.3094 - val_loss: 2.9120
# Epoch 77/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3819 - loss: 1.0878 - val_accuracy: 0.3084 - val_loss: 2.9101
# Epoch 78/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3819 - loss: 1.0855 - val_accuracy: 0.3092 - val_loss: 2.9262
# Epoch 79/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3826 - loss: 1.0794 - val_accuracy: 0.3092 - val_loss: 2.9416
# Epoch 80/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3826 - loss: 1.0783 - val_accuracy: 0.3078 - val_loss: 2.9580
# Epoch 81/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3831 - loss: 1.0737 - val_accuracy: 0.3096 - val_loss: 2.9097
# Epoch 82/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3831 - loss: 1.0734 - val_accuracy: 0.3102 - val_loss: 2.9367
# Epoch 83/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3834 - loss: 1.0688 - val_accuracy: 0.3092 - val_loss: 2.9434
# Epoch 84/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3835 - loss: 1.0681 - val_accuracy: 0.3089 - val_loss: 2.9242
# Epoch 85/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3839 - loss: 1.0647 - val_accuracy: 0.3088 - val_loss: 2.9401
# Epoch 86/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3843 - loss: 1.0593 - val_accuracy: 0.3094 - val_loss: 2.9728
# Epoch 87/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3843 - loss: 1.0567 - val_accuracy: 0.3096 - val_loss: 2.9316
# Epoch 88/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3845 - loss: 1.0545 - val_accuracy: 0.3087 - val_loss: 2.9813
# Epoch 89/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3850 - loss: 1.0503 - val_accuracy: 0.3070 - val_loss: 3.0455
# Epoch 90/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3853 - loss: 1.0467 - val_accuracy: 0.3086 - val_loss: 3.0092
# Epoch 91/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3854 - loss: 1.0434 - val_accuracy: 0.3082 - val_loss: 3.0380
# Epoch 92/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3859 - loss: 1.0400 - val_accuracy: 0.3081 - val_loss: 3.0600
# Epoch 93/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3860 - loss: 1.0376 - val_accuracy: 0.3088 - val_loss: 3.0203
# Epoch 94/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3863 - loss: 1.0361 - val_accuracy: 0.3099 - val_loss: 3.0129
# Epoch 95/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3866 - loss: 1.0309 - val_accuracy: 0.3081 - val_loss: 3.0285
# Epoch 96/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3868 - loss: 1.0298 - val_accuracy: 0.3097 - val_loss: 3.0284
# Epoch 97/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3870 - loss: 1.0275 - val_accuracy: 0.3085 - val_loss: 3.0307
# Epoch 98/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3872 - loss: 1.0242 - val_accuracy: 0.3066 - val_loss: 3.1094
# Epoch 99/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3874 - loss: 1.0216 - val_accuracy: 0.3091 - val_loss: 3.0240
# Epoch 100/100
# 1549/1549 - 20s - 13ms/step - accuracy: 0.3878 - loss: 1.0150 - val_accuracy: 0.3086 - val_loss: 3.0468
