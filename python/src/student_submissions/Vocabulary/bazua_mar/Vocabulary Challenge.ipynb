# %% [markdown]
# # Programa para leer y procesar los miserables

# %% [markdown]
# ## Leamos el libro en formato epub y guardemoslo en CSV

# %%
## Instalar dependencias
# !pip install ebooklib pandas bs4 unidecode nltk
# Out:
# Requirement already satisfied: ebooklib in /usr/local/lib/python3.11/dist-packages (0.18)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.11/dist-packages (0.0.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from ebooklib) (5.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from ebooklib) (1.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from bs4) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (4.12.2)

# %%
from ebooklib import epub
import pandas as pd
from bs4 import BeautifulSoup

# %%
#  Subir el archivo EPUB a Google Colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Asegurar que ITEM_DOCUMENT está definido
DOCUMENT_TYPE = epub.ITEM_DOCUMENT if hasattr(epub, "ITEM_DOCUMENT") else 9

def extract_text_from_epub(epub_path):
    book = epub.read_epub(epub_path)
    text_data = []

    for item in book.get_items():
        if item.get_type() == DOCUMENT_TYPE:
            soup = BeautifulSoup(item.get_content(), "html.parser")
            paragraphs = soup.find_all("p")
            for paragraph in paragraphs:
                text_data.append(paragraph.get_text(strip=True))

    return text_data

def save_text_to_csv(text_data, csv_path):
    df = pd.DataFrame(text_data, columns=["Text"])
    df.to_csv(csv_path, index=False, encoding="utf-8")

# %%
import glob
#No encontraba la ruta de donde estaba guardado el e-book y como mandarlo llamar
# Buscar archivos EPUB en toda tu unidad de Google Drive
epub_files = glob.glob("/content/drive/My Drive/**/*.epub", recursive=True)

# Mostrar archivos encontrados
print(epub_files)
# Out:
# ['/content/drive/My Drive/Colab Notebooks/datos/Los-miserables.epub']

# %%
# Ruta del archivo en Google Drive
epub_path = "/content/drive/My Drive/Colab Notebooks/datos/Los-miserables.epub"
csv_path = "/content/drive/My Drive/Colab Notebooks/datos/Los-miserables.csv"

# Convertir EPUB a CSV
text_data = extract_text_from_epub(epub_path)
save_text_to_csv(text_data, csv_path)

print(f"Archivo guardado en: {csv_path}")
# Out:
# /usr/local/lib/python3.11/dist-packages/ebooklib/epub.py:1395: UserWarning: In the future version we will turn default option ignore_ncx to True.
#   warnings.warn('In the future version we will turn default option ignore_ncx to True.')
# /usr/local/lib/python3.11/dist-packages/ebooklib/epub.py:1423: FutureWarning: This search incorrectly ignores the root element, and will be fixed in a future version.  If you rely on the current behaviour, change it to './/xmlns:rootfile[@media-type]'
#   for root_file in tree.findall('//xmlns:rootfile[@media-type]', namespaces={'xmlns': NAMESPACES['CONTAINERNS']}):
# Archivo guardado en: /content/drive/My Drive/Colab Notebooks/datos/Los-miserables.csv

# %% [markdown]
# ## Leer el csv y limpiarlo

# %%
import nltk
### La descarga de las stopwords solo hay que hacerla una vez
nltk.download("stopwords")
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import pandas as pd
import re
import unidecode
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Cargar stopwords en español
stop_words = set(stopwords.words("spanish"))

# %%
### Funcion para limpiar el texto
def clean_text(text):
    if not isinstance(text, str):  # Si el valor no es string, convertirlo
        return ""

    text = text.lower()  # Convertir a minúsculas
    text = unidecode.unidecode(text)  # Eliminar acentos
    text = re.sub(r"\s+", " ", text)  # Remover espacios extra
    text = text.translate(str.maketrans("", "", string.punctuation))  # Eliminar puntuación
    text = text.strip()  # Eliminar espacios al inicio y al final

    # Eliminar stopwords en español
    #words = text.split()
    #words = [word for word in words if word not in stop_words]
    #text = " ".join(words)

    return text

# %%
# Cargar el CSV que generamos con "Los Miserables"

csv_path = "/content/drive/My Drive/Colab Notebooks/datos/Los-miserables.csv"
df = pd.read_csv(csv_path)
### Los primeros 5 renglones
df.head(5)
# Out:
#              Text
# 0             NaN
# 1  Los miserables
# 2    Hugo, Victor
# 3          Novela
# 4             NaN

# %%
## Los últimos 5 renglones
df.tail()
# Out:
#                                                    Text
# 3022                  Una última palabra sobre Fantine.
# 3023  Todos nosotros tenemos una madre, la tierra. F...
# 3024  El cura creyó obrar bien, y posiblemente obró ...
# 3025  Fantine fue, pues, enterrada en el rincón grat...
# 3026                          [FIN DE LA PRIMERA PARTE]

# %%
# Aplicar limpieza a la columna "Text"
df["Text"] = df["Text"].astype(str).apply(clean_text)

# %%
df.head(5)
# Out:
#              Text
# 0             nan
# 1  los miserables
# 2     hugo victor
# 3          novela
# 4             nan

# %% [markdown]
#  Ahora hay que tokenizar

# %%
def tokenize(text):
    # Tokenizar en palabras
    tokens = word_tokenize(text)

    # Filtrar stopwords
    #tokens = [word for word in tokens if word not in stop_words]

    return tokens

df["Tokens"] = df["Text"].astype(str).apply(tokenize)


def tokenize_and_remove_stop_words(text):
    # Tokenizar en palabras
    tokens = word_tokenize(text)

    # Filtrar stopwords
    tokens = [word for word in tokens if word not in stop_words]

    return tokens

df["Tokens"] = df["Text"].astype(str).apply(tokenize)
df["Tokens_no_stopwords"] = df["Text"].astype(str).apply(tokenize_and_remove_stop_words)

# %%
df.head(5)
# Out:
#              Text             Tokens Tokens_no_stopwords
# 0             nan              [nan]               [nan]
# 1  los miserables  [los, miserables]        [miserables]
# 2     hugo victor     [hugo, victor]      [hugo, victor]
# 3          novela           [novela]            [novela]
# 4             nan              [nan]               [nan]

# %%
df.tail(5)
# Out:
#                                                    Text  \
# 3022                   una ultima palabra sobre fantine
# 3023  todos nosotros tenemos una madre la tierra fan...
# 3024  el cura creyo obrar bien y posiblemente obro b...
# 3025  fantine fue pues enterrada en el rincon gratui...
# 3026                            fin de la primera parte
#
#                                                  Tokens  \
# 3022             [una, ultima, palabra, sobre, fantine]
# 3023  [todos, nosotros, tenemos, una, madre, la, tie...
# 3024  [el, cura, creyo, obrar, bien, y, posiblemente...
# 3025  [fantine, fue, pues, enterrada, en, el, rincon...
# 3026                      [fin, de, la, primera, parte]
#
#                                     Tokens_no_stopwords
# 3022                         [ultima, palabra, fantine]
# 3023          [madre, tierra, fantine, devuelta, madre]
# 3024  [cura, creyo, obrar, bien, posiblemente, obro,...
# 3025  [fantine, pues, enterrada, rincon, gratuito, c...
# 3026                              [fin, primera, parte]

# %%
# Construir el vocabulario para el total
vocabulary = {}  # Diccionario de vocabulario
for tokens in df["Tokens"]:
    for token in tokens:
        if token not in vocabulary:
            vocabulary[token] = len(vocabulary)  # Asignar un índice único

# %%
vocabulary
# Out:
# {'nan': 0,
#  'los': 1,
#  'miserables': 2,
#  'hugo': 3,
#  'victor': 4,
#  'novela': 5,
#  'se': 6,
#  'reconocen': 7,
#  'derechos': 8,
#  'morales': 9,
#  'de': 10,
#  'obra': 11,
#  'dominio': 12,
#  'publico': 13,
#  'distribucion': 14,
#  'gratuita': 15,
#  'prohibida': 16,
#  'su': 17,
#  'venta': 18,
#  'y': 19,
#  'en': 20,
#  'medios': 21,
#  'ajenos': 22,
#  'a': 23,
#  'la': 24,
#  'fundacion': 25,
#  'carlos': 26,
#  'slim': 27,
#  'lago': 28,
#  'zurich': 29,
#  'plaza': 30,
#  'carso': 31,
#  'ii': 32,
#  'piso': 33,
#  '5': 34,
#  'col': 35,
#  'ampliacion': 36,
#  'granada': 37,
#  'c': 38,
#  'p': 39,
#  '11529': 40,
#  'ciudad': 41,
#  'mexico': 42,
#  'contactopruebatorg': 43,
#  'fantine': 44,
#  'un': 45,
#  'justo': 46,
#  'el': 47,
#  'senor': 48,
#  'myriel': 49,
#  '1815': 50,
#  'monsenor': 51,
#  'charlesfrancoisbienvenu': 52,
#  'era': 53,
#  'obispo': 54,
#  'digne': 55,
#  'anciano': 56,
#  'cerca': 57,
#  'setenta': 58,
#  'cinco': 59,
#  'anos': 60,
#  'ocupaba': 61,
#  'sede': 62,
#  'desde': 63,
#  '1806': 64,
#  'aunque': 65,
#  'este': 66,
#  'detalle': 67,
#  'no': 68,
#  'interesa': 69,
#  'manera': 70,
#  'alguna': 71,
#  'al': 72,
#  'fondo': 73,
#  'lo': 74,
#  'que': 75,
#  'vamos': 76,
#  'referir': 77,
#  'quiza': 78,
#  'sera': 79,
#  'inutil': 80,
#  'sea': 81,
#  'mas': 82,
#  'para': 83,
#  'ser': 84,
#  'exactos': 85,
#  'todo': 86,
#  'indicar': 87,
#  'aqui': 88,
#  'rumores': 89,
#  'las': 90,
#  'habladurias': 91,
#  'habian': 92,
#  'circulado': 93,
#  'acerca': 94,
#  'persona': 95,
#  'momento': 96,
#  'llego': 97,
#  'diocesis': 98,
#  'verdadero': 99,
#  'o': 100,
#  'falso': 101,
#  'hombres': 102,
#  'dice': 103,
#  'ocupa': 104,
#  'vida': 105,
#  'sobre': 106,
#  'destino': 107,
#  'tanto': 108,
#  'lugar': 109,
#  'como': 110,
#  'hacen': 111,
#  'hijo': 112,
#  'consejero': 113,
#  'del': 114,
#  'departamento': 115,
#  'aix': 116,
#  'nobleza': 117,
#  'toga': 118,
#  'deciase': 119,
#  'padre': 120,
#  'reservandole': 121,
#  'heredar': 122,
#  'puesto': 123,
#  'le': 124,
#  'habia': 125,
#  'casado': 126,
#  'muy': 127,
#  'pronto': 128,
#  'dieciocho': 129,
#  'veinte': 130,
#  'siguiendo': 131,
#  'una': 132,
#  'costumbre': 133,
#  'extendida': 134,
#  'entre': 135,
#  'familias': 136,
#  'parlamentarias': 137,
#  'charles': 138,
#  'obstante': 139,
#  'matrimonio': 140,
#  'dado': 141,
#  'mucho': 142,
#  'hablar': 143,
#  'buena': 144,
#  'presencia': 145,
#  'estatura': 146,
#  'pequena': 147,
#  'elegante': 148,
#  'gracioso': 149,
#  'inteligente': 150,
#  'toda': 151,
#  'primera': 152,
#  'parte': 153,
#  'estado': 154,
#  'consagrada': 155,
#  'mundo': 156,
#  'galanterias': 157,
#  'sobrevino': 158,
#  'revolucion': 159,
#  'precipitaronse': 160,
#  'sucesos': 161,
#  'diezmadas': 162,
#  'perseguidas': 163,
#  'acosadas': 164,
#  'dispersaron': 165,
#  'primeros': 166,
#  'dias': 167,
#  'emigro': 168,
#  'italia': 169,
#  'mujer': 170,
#  'murio': 171,
#  'alli': 172,
#  'enfermedad': 173,
#  'pecho': 174,
#  'padecia': 175,
#  'tiempo': 176,
#  'atras': 177,
#  'tenian': 178,
#  'hijos': 179,
#  'paso': 180,
#  'despues': 181,
#  'hundimiento': 182,
#  'antigua': 183,
#  'sociedad': 184,
#  'francesa': 185,
#  'caida': 186,
#  'propia': 187,
#  'familia': 188,
#  'tragicos': 189,
#  'espectaculos': 190,
#  '93': 191,
#  'espantosos': 192,
#  'aun': 193,
#  'emigrados': 194,
#  'veian': 195,
#  'lejos': 196,
#  'con': 197,
#  'aumento': 198,
#  'les': 199,
#  'prestaba': 200,
#  'terror': 201,
#  'hicieron': 202,
#  'germinar': 203,
#  'tal': 204,
#  'vez': 205,
#  'alma': 206,
#  'ideas': 207,
#  'renuncia': 208,
#  'soledad': 209,
#  'medio': 210,
#  'distracciones': 211,
#  'afectos': 212,
#  'ocupaban': 213,
#  'fue': 214,
#  'subitamente': 215,
#  'herido': 216,
#  'por': 217,
#  'uno': 218,
#  'estos': 219,
#  'golpes': 220,
#  'misteriosos': 221,
#  'terribles': 222,
#  'algunas': 223,
#  'veces': 224,
#  'llegan': 225,
#  'derribar': 226,
#  'lacerandole': 227,
#  'corazon': 228,
#  'hombre': 229,
#  'quien': 230,
#  'catastrofes': 231,
#  'publicas': 232,
#  'conmoverian': 233,
#  'si': 234,
#  'hiriesen': 235,
#  'existencia': 236,
#  'hacienda': 237,
#  'nadie': 238,
#  'hubiera': 239,
#  'podido': 240,
#  'decirlo': 241,
#  'solo': 242,
#  'sabia': 243,
#  'vuelta': 244,
#  'sacerdote': 245,
#  '1804': 246,
#  'cura': 247,
#  'parroco': 248,
#  'b': 249,
#  'brignolles': 250,
#  'ya': 251,
#  'vivia': 252,
#  'absoluto': 253,
#  'retiro': 254,
#  'hacia': 255,
#  'epoca': 256,
#  'coronacion': 257,
#  'pequeno': 258,
#  'asunto': 259,
#  'parroquia': 260,
#  'sabe': 261,
#  'punto': 262,
#  'fijo': 263,
#  'cual': 264,
#  'llevo': 265,
#  'paris': 266,
#  'otras': 267,
#  'personas': 268,
#  'poderosas': 269,
#  'solicitar': 270,
#  'amparo': 271,
#  'sus': 272,
#  'feligreses': 273,
#  'cardenal': 274,
#  'fesch': 275,
#  'dia': 276,
#  'emperador': 277,
#  'visitar': 278,
#  'tio': 279,
#  'digno': 280,
#  'esperaba': 281,
#  'antecamara': 282,
#  'hallo': 283,
#  'ante': 284,
#  'majestad': 285,
#  'napoleon': 286,
#  'ver': 287,
#  'aquel': 288,
#  'observaba': 289,
#  'cierta': 290,
#  'curiosidad': 291,
#  'volvio': 292,
#  'pregunto': 293,
#  'bruscamente': 294,
#  'es': 295,
#  'buen': 296,
#  'me': 297,
#  'mira': 298,
#  'dijo': 299,
#  'vos': 300,
#  'mirais': 301,
#  'yo': 302,
#  'miro': 303,
#  'gran': 304,
#  'ambos': 305,
#  'podemos': 306,
#  'sacar': 307,
#  'provecho': 308,
#  'aquella': 309,
#  'misma': 310,
#  'noche': 311,
#  'nombre': 312,
#  'algun': 313,
#  'quedo': 314,
#  'sorprendido': 315,
#  'enterarse': 316,
#  'sido': 317,
#  'nombrado': 318,
#  'verdad': 319,
#  'demas': 320,
#  'pocas': 321,
#  'conocido': 322,
#  'antes': 323,
#  'debia': 324,
#  'sufrir': 325,
#  'suerte': 326,
#  'todos': 327,
#  'recien': 328,
#  'llegados': 329,
#  'donde': 330,
#  'hay': 331,
#  'muchas': 332,
#  'bocas': 333,
#  'hablan': 334,
#  'cabezas': 335,
#  'piensan': 336,
#  'sufrirla': 337,
#  'fuera': 338,
#  'precisamente': 339,
#  'porque': 340,
#  'pero': 341,
#  'mezclaba': 342,
#  'eran': 343,
#  'ruido': 344,
#  'frases': 345,
#  'palabras': 346,
#  'menos': 347,
#  'palabrerias': 348,
#  'energico': 349,
#  'lenguaje': 350,
#  'mediodia': 351,
#  'fuere': 352,
#  'tras': 353,
#  'nueve': 354,
#  'episcopado': 355,
#  'residencia': 356,
#  'todas': 357,
#  'estas': 358,
#  'murmuraciones': 359,
#  'temas': 360,
#  'conversacion': 361,
#  'ocupan': 362,
#  'momentos': 363,
#  'pequenas': 364,
#  'ciudades': 365,
#  'gentes': 366,
#  'caido': 367,
#  'profundo': 368,
#  'olvido': 369,
#  'atrevido': 370,
#  'ellas': 371,
#  'osado': 372,
#  'ni': 373,
#  'siquiera': 374,
#  'recordarlas': 375,
#  'llegado': 376,
#  'acompanado': 377,
#  'solterona': 378,
#  'senorita': 379,
#  'baptistine': 380,
#  'hermana': 381,
#  'contaba': 382,
#  'diez': 383,
#  'servidumbre': 384,
#  'criada': 385,
#  'edad': 386,
#  'llamada': 387,
#  'magloire': 388,
#  'haber': 389,
#  'sirvienta': 390,
#  'llevaba': 391,
#  'ahora': 392,
#  'doble': 393,
#  'titulo': 394,
#  'doncella': 395,
#  'ama': 396,
#  'llaves': 397,
#  'alta': 398,
#  'palida': 399,
#  'delgada': 400,
#  'dulce': 401,
#  'encarnaba': 402,
#  'ideal': 403,
#  'expresa': 404,
#  'palabra': 405,
#  'respetable': 406,
#  'pues': 407,
#  'parece': 408,
#  'necesario': 409,
#  'haya': 410,
#  'madre': 411,
#  'venerable': 412,
#  'nunca': 413,
#  'bonita': 414,
#  'serie': 415,
#  'ininterrumpida': 416,
#  'buenas': 417,
#  'obras': 418,
#  'acabado': 419,
#  'extender': 420,
#  'especie': 421,
#  'blancura': 422,
#  'claridad': 423,
#  'envejecer': 424,
#  'adquirido': 425,
#  'podria': 426,
#  'llamarse': 427,
#  'belleza': 428,
#  'bondad': 429,
#  'juventud': 430,
#  'flacura': 431,
#  'madurez': 432,
#  'convertido': 433,
#  'transparencia': 434,
#  'esta': 435,
#  'diafanidad': 436,
#  'dejaba': 437,
#  'angel': 438,
#  'bien': 439,
#  'virgen': 440,
#  'parecia': 441,
#  'hecha': 442,
#  'sombra': 443,
#  'apenas': 444,
#  'tenia': 445,
#  'bastante': 446,
#  'cuerpo': 447,
#  'sexo': 448,
#  'poco': 449,
#  'materia': 450,
#  'contenia': 451,
#  'resplandor': 452,
#  'unos': 453,
#  'grandes': 454,
#  'ojos': 455,
#  'siempre': 456,
#  'bajos': 457,
#  'pretexto': 458,
#  'permaneciese': 459,
#  'tierra': 460,
#  'senora': 461,
#  'viejecita': 462,
#  'blanca': 463,
#  'gorda': 464,
#  'repleta': 465,
#  'afanosa': 466,
#  'sofocada': 467,
#  'primero': 468,
#  'causa': 469,
#  'actividad': 470,
#  'luego': 471,
#  'asma': 472,
#  'llegada': 473,
#  'instalaron': 474,
#  'palacio': 475,
#  'episcopal': 476,
#  'honores': 477,
#  'dispuestos': 478,
#  'decretos': 479,
#  'imperiales': 480,
#  'clasifican': 481,
#  'inmediatamente': 482,
#  'mariscal': 483,
#  'campo': 484,
#  'alcalde': 485,
#  'presidente': 486,
#  'visita': 487,
#  'hizo': 488,
#  'general': 489,
#  'prefecto': 490,
#  'terminada': 491,
#  'instalacion': 492,
#  'aguardo': 493,
#  'actos': 494,
#  'convierte': 495,
#  'bienvenu': 496,
#  'estaba': 497,
#  'contiguo': 498,
#  'hospital': 499,
#  'edificio': 500,
#  'amplio': 501,
#  'hermoso': 502,
#  'construido': 503,
#  'piedra': 504,
#  'principios': 505,
#  'siglo': 506,
#  'anterior': 507,
#  'henri': 508,
#  'puget': 509,
#  'doctor': 510,
#  'teologia': 511,
#  'facultad': 512,
#  'abad': 513,
#  'simore': 514,
#  '1712': 515,
#  'verdadera': 516,
#  'morada': 517,
#  'senorial': 518,
#  'respiraba': 519,
#  'grandeza': 520,
#  'habitaciones': 521,
#  'salones': 522,
#  'interiores': 523,
#  'patio': 524,
#  'honor': 525,
#  'ancho': 526,
#  'galerias': 527,
#  'arcos': 528,
#  'segun': 529,
#  'florentina': 530,
#  'jardines': 531,
#  'magnificos': 532,
#  'arboles': 533,
#  'comedor': 534,
#  'larga': 535,
#  'soberbia': 536,
#  'galeria': 537,
#  'bajo': 538,
#  'abria': 539,
#  'ofrecido': 540,
#  'banquete': 541,
#  '29': 542,
#  'julio': 543,
#  '1714': 544,
#  'monsenores': 545,
#  'brulart': 546,
#  'genlis': 547,
#  'arzobispoprincipe': 548,
#  'embrun': 549,
#  'antoine': 550,
#  'mesgrigny': 551,
#  'capuchino': 552,
#  'grasse': 553,
#  'philippe': 554,
#  'vendome': 555,
#  'prior': 556,
#  'francia': 557,
#  'sainthonore': 558,
#  'lerins': 559,
#  'francois': 560,
#  'berton': 561,
#  'grillon': 562,
#  'obispobaron': 563,
#  'vence': 564,
#  'cesar': 565,
#  'sabran': 566,
#  'forcalquier': 567,
#  'obisposenor': 568,
#  'glandeve': 569,
#  'jean': 570,
#  'soanen': 571,
#  'oratorio': 572,
#  'predicador': 573,
#  'ordinario': 574,
#  'rey': 575,
#  'senez': 576,
#  'retratos': 577,
#  'siete': 578,
#  'reverendos': 579,
#  'personajes': 580,
#  'decoraban': 581,
#  'esa': 582,
#  'sala': 583,
#  'fecha': 584,
#  'memorable': 585,
#  'grabada': 586,
#  'letras': 587,
#  'oro': 588,
#  'mesa': 589,
#  'marmol': 590,
#  'blanco': 591,
#  'estrecho': 592,
#  'jardin': 593,
#  'tres': 594,
#  'visito': 595,
#  'rogo': 596,
#  'director': 597,
#  'tuviera': 598,
#  'ir': 599,
#  'verle': 600,
#  'cuantos': 601,
#  'enfermos': 602,
#  'teneis': 603,
#  'veintiseis': 604,
#  'son': 605,
#  'contado': 606,
#  'camas': 607,
#  'replico': 608,
#  'estan': 609,
#  'proximas': 610,
#  'unas': 611,
#  'notado': 612,
#  'salas': 613,
#  'verdaderas': 614,
#  'celdas': 615,
#  'aire': 616,
#  'renueva': 617,
#  'dificilmente': 618,
#  'eso': 619,
#  'ha': 620,
#  'parecido': 621,
#  'ademas': 622,
#  'cuando': 623,
#  'penetra': 624,
#  'rayo': 625,
#  'sol': 626,
#  'resulta': 627,
#  'convalecientes': 628,
#  'he': 629,
#  'figurado': 630,
#  'epidemia': 631,
#  'ano': 632,
#  'hemos': 633,
#  'tenido': 634,
#  'tifus': 635,
#  'hace': 636,
#  'dos': 637,
#  'fiebre': 638,
#  'miliar': 639,
#  'juntan': 640,
#  'hasta': 641,
#  'cien': 642,
#  'sabemos': 643,
#  'hacer': 644,
#  'ello': 645,
#  'pensado': 646,
#  'quereis': 647,
#  'resignarse': 648,
#  'galeriacomedor': 649,
#  'planta': 650,
#  'baja': 651,
#  'guardo': 652,
#  'silencio': 653,
#  'instante': 654,
#  'cuantas': 655,
#  'creeis': 656,
#  'cabrian': 657,
#  'exclamo': 658,
#  'estupefacto': 659,
#  'recorria': 660,
#  'vista': 661,
#  'mirada': 662,
#  'tomaba': 663,
#  'medidas': 664,
#  'calculos': 665,
#  'hablando': 666,
#  'consigo': 667,
#  'mismo': 668,
#  'levantando': 669,
#  'voz': 670,
#  'anadio': 671,
#  'mirad': 672,
#  'voy': 673,
#  'deciros': 674,
#  'algo': 675,
#  'evidentemente': 676,
#  'error': 677,
#  'seis': 678,
#  'nosotros': 679,
#  'somos': 680,
#  'tenemos': 681,
#  'sitio': 682,
#  'sesenta': 683,
#  'repito': 684,
#  'mi': 685,
#  'casa': 686,
#  'vuestra': 687,
#  'devolvedme': 688,
#  'mia': 689,
#  'siguiente': 690,
#  'pobres': 691,
#  'estaban': 692,
#  'instalados': 693,
#  'bienes': 694,
#  'quedar': 695,
#  'arruinada': 696,
#  'recibia': 697,
#  'renta': 698,
#  'vitalicia': 699,
#  'quinientos': 700,
#  'francos': 701,
#  'presbiterado': 702,
#  'bastaban': 703,
#  'gastos': 704,
#  'personales': 705,
#  'asignacion': 706,
#  'quince': 707,
#  'mil': 708,
#  'instalo': 709,
#  'determino': 710,
#  'empleo': 711,
#  'suma': 712,
#  'modo': 713,
#  'consta': 714,
#  'nota': 715,
#  'escrita': 716,
#  'puno': 717,
#  'letra': 718,
#  'transcribimos': 719,
#  'arreglar': 720,
#  'seminario': 721,
#  '1500': 722,
#  'libras': 723,
#  'congregacion': 724,
#  'mision': 725,
#  '100': 726,
#  'lazaristas': 727,
#  'montdidier': 728,
#  'misiones': 729,
#  'extranjeras': 730,
#  '200': 731,
#  'espiritu': 732,
#  'santo': 733,
#  '150': 734,
#  'establecimientos': 735,
#  'religiosos': 736,
#  'santa': 737,
#  'sociedades': 738,
#  'caridad': 739,
#  'maternal': 740,
#  '300': 741,
#  'idem': 742,
#  'arles': 743,
#  '50': 744,
#  'mejora': 745,
#  'prisiones': 746,
#  '400': 747,
#  'alivio': 748,
#  'rescate': 749,
#  'presos': 750,
#  '500': 751,
#  'liberar': 752,
#  'padres': 753,
#  'deudas': 754,
#  '1000': 755,
#  'suplemento': 756,
#  'maestros': 757,
#  'escuelas': 758,
#  '2000': 759,
#  'posito': 760,
#  'altos': 761,
#  'alpes': 762,
#  'senoras': 763,
#  'manosque': 764,
#  'sisteron': 765,
#  'ensenanza': 766,
#  'ninas': 767,
#  'indigentes': 768,
#  '6000': 769,
#  'gasto': 770,
#  'personal': 771,
#  'total': 772,
#  '15000': 773,
#  'durante': 774,
#  'ocupo': 775,
#  'cambio': 776,
#  'nada': 777,
#  'arreglo': 778,
#  'llamaba': 779,
#  'esto': 780,
#  'visto': 781,
#  'tener': 782,
#  'regulados': 783,
#  'aceptado': 784,
#  'absoluta': 785,
#  'sumision': 786,
#  'hermano': 787,
#  'amigo': 788,
#  'naturaleza': 789,
#  'superior': 790,
#  'iglesia': 791,
#  'amaba': 792,
#  'veneraba': 793,
#  'sencillamente': 794,
#  'hablaba': 795,
#  'ella': 796,
#  'inclinaba': 797,
#  'obraba': 798,
#  'adheria': 799,
#  'murmuro': 800,
#  'observarlo': 801,
#  'reservado': 802,
#  'unidos': 803,
#  'pension': 804,
#  'sumaban': 805,
#  'vivian': 806,
#  'aquellas': 807,
#  'mujeres': 808,
#  'aldea': 809,
#  'venia': 810,
#  'podia': 811,
#  'incluso': 812,
#  'obsequiarle': 813,
#  'gracias': 814,
#  'severa': 815,
#  'economia': 816,
#  'administracion': 817,
#  'meses': 818,
#  'hallaba': 819,
#  'ando': 820,
#  'holgado': 821,
#  'creo': 822,
#  'reclamado': 823,
#  'debe': 824,
#  'carruaje': 825,
#  'visitas': 826,
#  'obispos': 827,
#  'otros': 828,
#  'tiempos': 829,
#  'vaya': 830,
#  'tiene': 831,
#  'usted': 832,
#  'razon': 833,
#  'presento': 834,
#  'reclamacion': 835,
#  'consejo': 836,
#  'tomando': 837,
#  'consideracion': 838,
#  'demanda': 839,
#  'voto': 840,
#  'anual': 841,
#  'epigrafe': 842,
#  'posta': 843,
#  'pastorales': 844,
#  'aquello': 845,
#  'gritar': 846,
#  'burguesia': 847,
#  'local': 848,
#  'motivo': 849,
#  'senador': 850,
#  'imperio': 851,
#  'antiguo': 852,
#  'miembro': 853,
#  'favorable': 854,
#  '18': 855,
#  'brumario': 856,
#  'agraciado': 857,
#  'magnifica': 858,
#  'senaduria': 859,
#  'escribio': 860,
#  'ministro': 861,
#  'cultos': 862,
#  'bigot': 863,
#  'preameneu': 864,
#  'irritada': 865,
#  'confidencial': 866,
#  'extraemos': 867,
#  'lineas': 868,
#  'autenticas': 869,
#  'carruajes': 870,
#  'poblacion': 871,
#  'cuatro': 872,
#  'habitantes': 873,
#  'viajes': 874,
#  'falta': 875,
#  'correra': 876,
#  'region': 877,
#  'montanosa': 878,
#  'carreteras': 879,
#  'puede': 880,
#  'andar': 881,
#  'caballo': 882,
#  'puente': 883,
#  'durance': 884,
#  'chateauarnoux': 885,
#  'sostener': 886,
#  'carretas': 887,
#  'bueyes': 888,
#  'curas': 889,
#  'avarientos': 890,
#  'ambiciosos': 891,
#  'llegar': 892,
#  'papel': 893,
#  'apostol': 894,
#  'necesita': 895,
#  'silla': 896,
#  'quiere': 897,
#  'lujo': 898,
#  'antiguos': 899,
#  'oh': 900,
#  'tropa': 901,
#  'conde': 902,
#  'cosas': 903,
#  'marcharan': 904,
#  'nos': 905,
#  'librado': 906,
#  'sotanas': 907,
#  'abajo': 908,
#  'papa': 909,
#  'asuntos': 910,
#  'roma': 911,
#  'entonces': 912,
#  'embrollados': 913,
#  'cuanto': 914,
#  'estoy': 915,
#  'etc': 916,
#  'contrario': 917,
#  'regocijo': 918,
#  'comenzado': 919,
#  'preciso': 920,
#  'acabara': 921,
#  'arregladas': 922,
#  'seran': 923,
#  'fin': 924,
#  'entrego': 925,
#  'concebida': 926,
#  'forma': 927,
#  'dar': 928,
#  'caldo': 929,
#  'carne': 930,
#  '250': 931,
#  'draguignan': 932,
#  'ninos': 933,
#  'expositos': 934,
#  'huerfanos': 935,
#  '3000': 936,
#  'presupuesto': 937,
#  'episcopales': 938,
#  'dispensa': 939,
#  'amonestaciones': 940,
#  'predicaciones': 941,
#  'bendiciones': 942,
#  'iglesias': 943,
#  'capillas': 944,
#  'matrimonios': 945,
#  'cobraba': 946,
#  'ricos': 947,
#  'rigor': 948,
#  'presteza': 949,
#  'cabo': 950,
#  'afluyeron': 951,
#  'ofrendas': 952,
#  'dinero': 953,
#  'llamaban': 954,
#  'puerta': 955,
#  'buscar': 956,
#  'limosna': 957,
#  'depositarla': 958,
#  'convirtio': 959,
#  'tesorero': 960,
#  'beneficios': 961,
#  'cajero': 962,
#  'estrecheces': 963,
#  'manos': 964,
#  'pasaban': 965,
#  'considerables': 966,
#  'sumas': 967,
#  'cambiara': 968,
#  'genero': 969,
#  'anadiera': 970,
#  'menor': 971,
#  'cosa': 972,
#  'superflua': 973,
#  'miseria': 974,
#  'fraternidad': 975,
#  'arriba': 976,
#  'asi': 977,
#  'recibido': 978,
#  'agua': 979,
#  'arrojada': 980,
#  'seca': 981,
#  'alcanzaba': 982,
#  'suficiente': 983,
#  'despojaba': 984,
#  'suyo': 985,
#  'anunciaran': 986,
#  'nombres': 987,
#  'bautismo': 988,
#  'encabezar': 989,
#  'escritos': 990,
#  'cartas': 991,
#  'elegido': 992,
#  'instinto': 993,
#  'afectuoso': 994,
#  'ofrecia': 995,
#  'significado': 996,
#  'otro': 997,
#  'haremos': 998,
#  'ellos': 999,
#  ...}

# %%
# Guardar vocabulario en Parquet
vocab_df = pd.DataFrame(list(vocabulary.items()), columns=["Word", "Index"])
vocab_parquet_path = "/content/drive/My Drive/Colab Notebooks/datos/vocabulary.parquet"
vocab_df.to_parquet(vocab_parquet_path, index=False)

# %%
import collections #Para usar el contador de palabras

# %%
# Contador de palabras basado en el vocabulario
word_counts = collections.Counter()
word_counts_nostop_words = collections.Counter()

# Contar frecuencia solo para palabras en el vocabulario
for tokens in df["Tokens"]:
    for token in tokens:
        if token in vocabulary:
            word_counts[token] += 1

# Contar frecuencia solo para palabras en el vocabulario
for tokens in df["Tokens_no_stopwords"]:
    for token in tokens:
        if token in vocabulary:
            word_counts_nostop_words[token] += 1

#Calcular estadísticas considerando todas las palabras
total_words = sum(word_counts.values())  # Total de palabras en el texto
unique_words = len(word_counts)  # Palabras únicas en el vocabulario
most_common_words = word_counts.most_common(100)  # 100 más frecuentes
least_common_words = word_counts.most_common()[-100:]  # 100 menos frecuentes

#Calcular estadísticas quitando stop_words
total_words_no_sw = sum(word_counts_nostop_words.values())  # Total de palabras en el texto
unique_words_no_sw = len(word_counts_nostop_words)  # Palabras únicas en el vocabulario
most_common_words_no_sw = word_counts_nostop_words.most_common(100)  # 100 más frecuentes
least_common_words_no_sw = word_counts_nostop_words.most_common()[-100:]  # 100 menos frecuentes

# %% [markdown]
# Total con stopwords

# %%
# Imprimir resultados
print(f" Total de palabras en el libro: {total_words}")
print(f" Número de palabras únicas en el vocabulario: {unique_words}")
print("\n 100 palabras más frecuentes:")
print(most_common_words)
print("\n100 palabras menos frecuentes:")
print(least_common_words)
# Out:
#  Total de palabras en el libro: 109287
#  Número de palabras únicas en el vocabulario: 13165
#
#  100 palabras más frecuentes:
# [('de', 5325), ('la', 3918), ('que', 3818), ('el', 3394), ('y', 3121), ('en', 2836), ('a', 2488), ('se', 1681), ('un', 1601), ('no', 1498), ('los', 1353), ('una', 1319), ('su', 1245), ('las', 935), ('por', 935), ('con', 924), ('habia', 857), ('del', 813), ('al', 755), ('es', 749), ('lo', 719), ('le', 667), ('era', 650), ('como', 572), ('mas', 513), ('para', 503), ('senor', 447), ('esta', 414), ('pero', 372), ('hombre', 363), ('si', 358), ('sus', 344), ('todo', 327), ('me', 326), ('sin', 311), ('obispo', 286), ('dijo', 281), ('cuando', 274), ('estaba', 273), ('sobre', 269), ('dos', 264), ('este', 261), ('aquel', 253), ('mi', 244), ('ya', 229), ('hacia', 219), ('yo', 218), ('esto', 218), ('madeleine', 214), ('tenia', 212), ('jean', 200), ('ha', 199), ('fantine', 194), ('valjean', 192), ('aquella', 190), ('hay', 186), ('he', 182), ('ser', 181), ('muy', 178), ('javert', 175), ('nada', 174), ('mismo', 173), ('o', 164), ('os', 163), ('poco', 158), ('tan', 158), ('bien', 157), ('ni', 156), ('ella', 155), ('quien', 150), ('alcalde', 149), ('vez', 148), ('despues', 146), ('fue', 145), ('todos', 141), ('puerta', 137), ('anos', 136), ('hubiera', 133), ('cual', 133), ('donde', 131), ('dios', 130), ('mujer', 127), ('momento', 125), ('tiempo', 124), ('sido', 124), ('casa', 123), ('son', 121), ('aqui', 120), ('noche', 119), ('hecho', 118), ('tres', 115), ('dia', 114), ('luego', 113), ('cabeza', 113), ('decir', 112), ('voz', 111), ('alli', 107), ('ojos', 107), ('monsenor', 105), ('aun', 105)]
#
# 100 palabras menos frecuentes:
# [('reprobo', 1), ('emocionantes', 1), ('florecer', 1), ('palidos', 1), ('fulgor', 1), ('sepultura', 1), ('recluyo', 1), ('lugares', 1), ('conversaciones', 1), ('bejean', 1), ('bojean', 1), ('boujean', 1), ('almibarado', 1), ('rehusado', 1), ('perillanes', 1), ('sucia', 1), ('abundaron', 1), ('abonada', 1), ('drapeau', 1), ('blanc', 1), ('ensenara', 1), ('partidarios', 1), ('despavorida', 1), ('reflexionando', 1), ('puestos', 1), ('velaban', 1), ('colgo', 1), ('esperara', 1), ('inconscientemente', 1), ('ensimismamiento', 1), ('candela', 1), ('boquiabierta', 1), ('retenido', 1), ('embargada', 1), ('barrote', 1), ('guardaria', 1), ('maestra', 1), ('lateral', 1), ('registrado', 1), ('conducian', 1), ('peldanos', 1), ('deshecha', 1), ('huella', 1), ('penultima', 1), ('obtuvo', 1), ('envolvio', 1), ('embalaba', 1), ('mordiendo', 1), ('comprobado', 1), ('migas', 1), ('encontradas', 1), ('pesquisas', 1), ('enrojecidos', 1), ('violencias', 1), ('integros', 1), ('entranas', 1), ('obligan', 1), ('doblar', 1), ('leerlo', 1), ('servira', 1), ('sonidos', 1), ('inarticulados', 1), ('persiguiendome', 1), ('turbaria', 1), ('alboroto', 1), ('murmullos', 1), ('protestas', 1), ('ambiente', 1), ('respirable', 1), ('integramente', 1), ('objecion', 1), ('correcto', 1), ('amuralladas', 1), ('retirarse', 1), ('quedarse', 1), ('aventurar', 1), ('desfallecer', 1), ('insista', 1), ('evadido', 1), ('mintio', 1), ('seguidas', 1), ('holocausto', 1), ('valga', 1), ('reparo', 1), ('singularidad', 1), ('bujia', 1), ('marchando', 1), ('brumas', 1), ('alejaba', 1), ('devuelta', 1), ('posiblemente', 1), ('reservar', 1), ('simplifico', 1), ('estricto', 1), ('enterrada', 1), ('gratuito', 1), ('cementerio', 1), ('encontrados', 1), ('sufrio', 1), ('promiscuidad', 1)]

# %% [markdown]
# Total sin stopwords

# %%
# Imprimir resultados
print(f" Total de palabras en el libro sin considerar stopwords: {total_words_no_sw}")
print(f" Número de palabras únicas en el vocabulario sin considerar stopwords: {unique_words_no_sw}")
print("\n 100 palabras más frecuentes sin considerar stopwords:")
print(most_common_words_no_sw)
print("\n100 palabras menos frecuentes sin considerar stopwords:")
print(least_common_words_no_sw)
# Out:
#  Total de palabras en el libro: 57219
#  Número de palabras únicas en el vocabulario: 12991
#
#  100 palabras más frecuentes:
# [('habia', 857), ('mas', 513), ('senor', 447), ('hombre', 363), ('si', 358), ('obispo', 286), ('dijo', 281), ('dos', 264), ('aquel', 253), ('hacia', 219), ('madeleine', 214), ('tenia', 212), ('jean', 200), ('fantine', 194), ('valjean', 192), ('aquella', 190), ('ser', 181), ('javert', 175), ('mismo', 173), ('tan', 158), ('bien', 157), ('alcalde', 149), ('vez', 148), ('despues', 146), ('puerta', 137), ('anos', 136), ('dios', 130), ('mujer', 127), ('momento', 125), ('tiempo', 124), ('sido', 124), ('casa', 123), ('aqui', 120), ('noche', 119), ('hecho', 118), ('tres', 115), ('dia', 114), ('luego', 113), ('cabeza', 113), ('decir', 112), ('voz', 111), ('alli', 107), ('ojos', 107), ('monsenor', 105), ('aun', 105), ('todas', 104), ('vida', 102), ('parecia', 101), ('senora', 100), ('solo', 98), ('bajo', 98), ('volvio', 93), ('pues', 93), ('gran', 92), ('hacer', 92), ('entonces', 92), ('toda', 89), ('alma', 88), ('nombre', 86), ('hermana', 86), ('siempre', 86), ('hizo', 86), ('preciso', 86), ('especie', 85), ('casi', 84), ('francos', 83), ('asi', 83), ('dicho', 83), ('hace', 82), ('manana', 82), ('habian', 81), ('ahora', 81), ('mano', 81), ('habitacion', 81), ('decia', 80), ('hombres', 79), ('palabras', 79), ('visto', 79), ('nadie', 76), ('magloire', 76), ('podia', 76), ('cosa', 76), ('tambien', 76), ('cerca', 75), ('buen', 75), ('madre', 74), ('cada', 74), ('menos', 73), ('mal', 72), ('respondio', 72), ('ver', 70), ('iba', 70), ('hora', 70), ('calle', 70), ('paso', 69), ('mirada', 69), ('luz', 69), ('cosas', 68), ('palabra', 66), ('cuatro', 65)]
#
# 100 palabras menos frecuentes:
# [('reprobo', 1), ('emocionantes', 1), ('florecer', 1), ('palidos', 1), ('fulgor', 1), ('sepultura', 1), ('recluyo', 1), ('lugares', 1), ('conversaciones', 1), ('bejean', 1), ('bojean', 1), ('boujean', 1), ('almibarado', 1), ('rehusado', 1), ('perillanes', 1), ('sucia', 1), ('abundaron', 1), ('abonada', 1), ('drapeau', 1), ('blanc', 1), ('ensenara', 1), ('partidarios', 1), ('despavorida', 1), ('reflexionando', 1), ('puestos', 1), ('velaban', 1), ('colgo', 1), ('esperara', 1), ('inconscientemente', 1), ('ensimismamiento', 1), ('candela', 1), ('boquiabierta', 1), ('retenido', 1), ('embargada', 1), ('barrote', 1), ('guardaria', 1), ('maestra', 1), ('lateral', 1), ('registrado', 1), ('conducian', 1), ('peldanos', 1), ('deshecha', 1), ('huella', 1), ('penultima', 1), ('obtuvo', 1), ('envolvio', 1), ('embalaba', 1), ('mordiendo', 1), ('comprobado', 1), ('migas', 1), ('encontradas', 1), ('pesquisas', 1), ('enrojecidos', 1), ('violencias', 1), ('integros', 1), ('entranas', 1), ('obligan', 1), ('doblar', 1), ('leerlo', 1), ('servira', 1), ('sonidos', 1), ('inarticulados', 1), ('persiguiendome', 1), ('turbaria', 1), ('alboroto', 1), ('murmullos', 1), ('protestas', 1), ('ambiente', 1), ('respirable', 1), ('integramente', 1), ('objecion', 1), ('correcto', 1), ('amuralladas', 1), ('retirarse', 1), ('quedarse', 1), ('aventurar', 1), ('desfallecer', 1), ('insista', 1), ('evadido', 1), ('mintio', 1), ('seguidas', 1), ('holocausto', 1), ('valga', 1), ('reparo', 1), ('singularidad', 1), ('bujia', 1), ('marchando', 1), ('brumas', 1), ('alejaba', 1), ('devuelta', 1), ('posiblemente', 1), ('reservar', 1), ('simplifico', 1), ('estricto', 1), ('enterrada', 1), ('gratuito', 1), ('cementerio', 1), ('encontrados', 1), ('sufrio', 1), ('promiscuidad', 1)]
